# %% [markdown]
# # A. Introduction
# Transit-Oriented Development (TOD) is a city planning approach that focuses on creating mixed-use communities centered around public transportation hubs. Picture neighborhoods where homes, restaurants, shops, and parks are just a short, easy walk—usually 5 to 10 minutes, or around 400 to 800 meters—from a transit station. These areas are thoughtfully designed to reduce the need for cars, making neighborhoods safer and more accessible for people who prefer walking, cycling, or using public transit.
#
# Plus, the Multi-Family Zoning Requirement for MBTA Communities was introduced in January 2021 as a part of Massachusetts' economic development bill. Its goal is to help solve the state's housing shortage. It aims to encourage more multi-family housing near public transit. This rule requires MBTA-served communities to create zoning districts that permit multi-family housing by right. These districts must be close to transit stations.
#
#
# The TOD approach aligns closely with the goals of the MBTA Communities Zoning Requirement. By emphasizing high-density, multi-family housing in proximity to transit stations, TOD projects directly contribute to alleviating the housing shortage while enhancing accessibility to public transportation. This synergy not only supports the policy's intent to expand housing opportunities but also reinforces sustainability objectives by encouraging public transit use over car dependency, reducing environmental impact, and creating more walkable, connected communities.
#
# For this section, we focus on identifying the best locations for TOD in the great Boston area. By mainly analyzing ridership, convenience and cost-efficiency factors, we aim to support the goals of the MBTA zoning requirement and promote sustainable urban growth.

# %% [markdown]
# # B.MBTA Communities
#
# To choose suitable locations for a TOD project, it is essential to consider areas near urban sub-centers that act as hubs for economic and social activity. These locations, such as secondary city centers or employment clusters, ensure a strong demand for transit and nearby amenities. Proximity to major transit stations, such as metro or rail stops within a walkable distance of 400-800 meters, is a key factor. The site should also support high-density development, including residential, commercial, or mixed-use spaces, to make the best use of the land.

# %% [markdown]
# For the purposes of this Needs Assessment, we will separate the great Boston area into several regions according to the Boston Region Metropolitan Planning Organization (MPO) as follows.
#
# **The Boston Business District**
#
# The Central Area is a densely developed region known as the Boston Business District (BBD). This district includes "Boston Proper" and the expanding South Boston waterfront. Boston Proper lies south of the Charles River, bordered by Massachusetts Avenue and Interstate 93 to the west and southeast. The Fort Point Channel divides Boston Proper from the South Boston waterfront. The boundary of the South Boston waterfront runs along Broadway from the Fort Point Channel to the South Boston Bypass Road, then follows Cypher Street, D Street, and Summer Street up to the Reserved Channel.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **The Central Area**
#
# The defined **central area** is where the radial transit services meet and total employment in the area exceeds the total population. It includes most of Boston and nine nearby municipalities: **Brookline, Cambridge, Somerville, Medford, Malden, Everett, Revere, Chelsea, and Winthrop**. Four Boston neighborhoods, Hyde Park, West Roxbury, Roslindale, and Mattapan are not included in the Central Area because their density and travel patterns more closely resemble the neighboring suburban communities.
#
# Based on the above discussion on TOD project site selection, the central area will be the key areas.

# %% [markdown]
# **Radial Corridors**
#
# The area served by the MBTA spreads out from the Boston Business District to the six surrounding areas, which we can call **Radial Corridors**. It can help us analyze the general direction and service range of each line.
#
# * **Northeast Corridor**
#
#   The Blue Line serves this corridor. The Newburyport commuter rail lines also serve this corridor.
#
# * **North Corridor**
#
#   The Orange Line serves this corridor. The Haverhill and Lowell lines also serve this corridor.
#
# * **Northwest Corridor**
#
#   The Red Line serves this corridor. The Fitchburg Line also serves this corridor.
#
# * **West Corridor**
#
#   Three of the Green Line branches serve this corridor. The Worcester commuter rail line also serves this corridor.
#
# * **Southwest Corridor**
#
#   This corridor is also served by the Orange Line. The Franklin and Providence/Stoughton lines and Amtrak's Northeast Corridor also serve this corridor.
#
# * **Southeast Corridor**
#
#   Both branches of the Red Line, including Mattapan trains, serve this corridor. Commuter rail service is provided by the Middleborough/Lakeville, Kingston/Plymouth, and Greenbush lines.

# %% [markdown]
# ---
# After making a rough observation and division of the regional structure of the Boston area, we now load a dataset of MBTA communities offered by Executive Office of Housing and Livable Communities of Massachusetts.

# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd

file_path = 'https://drive.google.com/uc?export=download&id=1vOcEskeL0EoOsvW6gJhX1I8fqdFWkig_'

mbta_com = pd.read_csv(file_path)

mbta_com.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-e58de9ffe726> in <cell line: 0>()
#       7 file_path = 'https://drive.google.com/file/d/1CfBY3qrJdLeiChWDSY92omlzX3CGDEKi/view?usp=drive_link'
#       8
# ----> 9 missing_migrant_global = pd.read_csv(file_path)
#      10
#      11 missing_migrant_global.columns.tolist()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     726
#     727     # open URLs
# --> 728     ioargs = _get_filepath_or_buffer(
#     729         path_or_buf,
#     730         encoding=encoding,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382         # assuming storage_options is to be interpreted as headers
#     383         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384         with urlopen(req_info) as req:
#     385             content_encoding = req.headers.get("Content-Encoding", None)
#     386             if content_encoding == "gzip":
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     287     import urllib.request
#     288
# --> 289     return urllib.request.urlopen(*args, **kwargs)
#     290
#     291
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.11/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 401: Unauthorized

# %% [markdown]
# **Data Dictionary**
#
# * **community**: Community Name
#
# * **community_category**:Categories of MBTA Communities
#
#   The draft guidelines separate the MBTA communities into four categories based on the level of public-transit service in that city or town:
#
#   * **Rapid Transit Community**: Community with a subway station within its border or within a ½ mile of its border even if there is one or more commuter rail stations or MBTA bus lines in that community.
#
#   * **Bus Service Community**:Community with a bus station or MBTA bus stop within its border or within ½ mile of its border AND no subway station or commuter rail station in or within ½ mile of its border.
#
#   * **Commuter Rail Community**: Community with a commuter rail station within its border or within a ½ mile of its border AND no subway station in or within a ½ mile of its border.
#
#   * **Adjacent Community**: Community with no transit station within its border or within ½ mile of its border.
#
# * **2020_Housing_Units**: Total housing units in 2020
#
# * **minimum_multi_family_unit capacity**: Minimum Multifamily Unit Capacity. Displays the minimum amount of multifamily housing a community needs to plan for according to policy requirements.
#
# * **unit_cpacity_of_total_housing_units**: Multi-family housing units as a percentage of total housing units
#
# * **minimum_land_area**: Minimum lot area. Refers to the minimum lot area required to meet multi-family residential planning requirements.
#
# * **developable_station_area**: Developable site area. Indicates the area that can be used for development in areas close to transportation sites. Developable station area is derived by taking the area of a half-mile circle around an MBTA commuter rail station, rapid transit station, or ferry terminal and removing any areas comprised of excluded land.
#
# * **percent_of_district_to_be_located_in_station_area**: The proportion of the site area that needs to be zoned for multi-family housing

# %% [markdown]
# Now let's look at the types of MBTA communities in this dataset.

# %%
# Calculate the total count for each community category
category_counts = mbta_com['community_category'].value_counts()

# Display the result
print(category_counts)
# Out:
# community_category
# Commuter Rail          72
# Adjacent community     58
# Adjacent small town    35
# Rapid Transit          12
# Name: count, dtype: int64

# %% [markdown]
# Obviously, our next focus will be on the 12 communities in the Rapid Transit category.

# %%
# Filter rows where community_category is 'Rapid Transit'
rapid_transit_com = mbta_com[mbta_com['community_category'] == 'Rapid Transit']

# Display the filtered data
rapid_transit_com
# Out:
#       community community_category 2020_Housing_Units  \
# 20    Braintree      Rapid Transit             15,077
# 23    Brookline      Rapid Transit             27,961
# 25    Cambridge      Rapid Transit             53,907
# 30      Chelsea      Rapid Transit             14,554
# 41      Everett      Rapid Transit             18,208
# 79       Malden      Rapid Transit             27,721
# 87      Medford      Rapid Transit             25,770
# 96       Milton      Rapid Transit              9,844
# 103      Newton      Rapid Transit             33,320
# 119      Quincy      Rapid Transit             47,009
# 124      Revere      Rapid Transit             24,539
# 138  Somerville      Rapid Transit             36,269
#
#     minimum_multi_family_unit capacity unit_cpacity_of_total_housing_units  \
# 20                               3,769                                 25%
# 23                               6,990                                 25%
# 25                              13,477                                 25%
# 30                               3,639                                 25%
# 41                               4,552                                 25%
# 79                               6,930                                 25%
# 87                               6,443                                 25%
# 96                               2,461                                 25%
# 103                              8,330                                 25%
# 119                             11,752                                 25%
# 124                              6,135                                 25%
# 138                              9,067                                 25%
#
#     minimum_land_area developable_station_area  \
# 20                 50                      485
# 23                 41                    1,349
# 25                 32                    1,392
# 30                 14                      608
# 41                 22                      200
# 79                 31                      484
# 87                 35                      714
# 96                 50                      404
# 103                50                    2,833
# 119                50                    1,222
# 124                27                      457
# 138                24                    1,314
#
#     percent_of_district_to_be_located_in_station_area
# 20                                                50%
# 23                                                90%
# 25                                                90%
# 30                                                75%
# 41                                                20%
# 79                                                50%
# 87                                                75%
# 96                                                50%
# 103                                               90%
# 119                                               90%
# 124                                               50%
# 138                                               90%

# %% [markdown]
# By comparison, we can find that all of the nine central areas mentioned above are Rapid Transit Communities except **Winthrop**. By looking at the regional map, we can find that because it is located in the northeast corner of the airport, there is indeed no transit passing through the community, so it is classified as an Adjacent Community. In addition, **Braintree, Milton, Newton, and Quincy**, four other communities in southern Boston, are listed as Rapid Transit Communities.

# %% [markdown]
# Before we look at which subway stations are within the jurisdiction of these Rapid Transit Communities, we may need to locate them by their zip code. Let's first load a dataset of Massachusetts zip codes.

# %%
file_path = 'https://drive.google.com/uc?export=download&id=16qMJt20hw0dT465FLW-yU6O0kpFk7vV_'

ma_zip = pd.read_csv(file_path)

# Ensure ZIP codes are 5 digits by adding leading zeros where necessary
ma_zip['zip_code'] = ma_zip['zip_code'].apply(lambda x: f"{int(x):05d}")

ma_zip
# Out:
#     zip_code postal_area_name        city     county  \
# 0      01001           Agawam      Agawam    Hampden
# 1      01002          Amherst     Amherst  Hampshire
# 2      01002          Amherst  Shutesbury   Franklin
# 3      01003          Amherst     Amherst  Hampshire
# 4      01004          Amherst     Amherst  Hampshire
# ..       ...              ...         ...        ...
# 748    02783          Taunton    Taunton     Bristol
# 749    02790         Westport    Westport    Bristol
# 750    02791   Westport Point    Westport    Bristol
# 751    05501          Andover     Andover      Essex
# 752    05544          Andover     Andover      Essex
#
#                     chia_region
# 0         Western Massachusetts
# 1         Western Massachusetts
# 2         Western Massachusetts
# 3         Western Massachusetts
# 4         Western Massachusetts
# ..                          ...
# 748                Metro South
# 749                  Southcoast
# 750                  Southcoast
# 751  Northeastern Massachusetts
# 752  Northeastern Massachusetts
#
# [753 rows x 5 columns]

# %% [markdown]
# Next, we will filter out the postal codes in the Rapid Transit Communities area. There may be duplicates, so for convenience, we will keep the first column that appears.

# %%
# Match cities from the ZIP code dataset with communities in Rapid Transit
rtc_data = ma_zip[ma_zip['city'].isin(rapid_transit_com['community'])]

# Ensure ZIP codes are 5 digits by adding leading zeros where necessary
rtc_data['zip_code'] = rtc_data['zip_code'].apply(lambda x: f"{int(x):05d}")

# Remove duplicates in rtc_data based on the zip_code column, keeping the first occurrence
rtc_data = rtc_data.drop_duplicates(subset='zip_code', keep='first')

# Display or save the filtered data
rtc_data
# Out:
#     zip_code    postal_area_name        city     county    chia_region
# 473    02138           Cambridge   Cambridge  Middlesex   Metro Boston
# 474    02139           Cambridge   Cambridge  Middlesex   Metro Boston
# 475    02140           Cambridge   Cambridge  Middlesex   Metro Boston
# 476    02141           Cambridge   Cambridge  Middlesex   Metro Boston
# 477    02142           Cambridge   Cambridge  Middlesex   Metro Boston
# 478    02143          Somerville  Somerville  Middlesex   Metro Boston
# 479    02144          Somerville  Somerville  Middlesex   Metro Boston
# 480    02145          Somerville  Somerville  Middlesex   Metro Boston
# 481    02146           Brookline   Brookline    Norfolk   Metro Boston
# 482    02148              Malden      Malden  Middlesex   Metro Boston
# 483    02149             Everett     Everett  Middlesex   Metro Boston
# 484    02150             Chelsea     Chelsea    Suffolk   Metro Boston
# 485    02151              Revere      Revere    Suffolk   Metro Boston
# 487    02153             Medford     Medford  Middlesex   Metro Boston
# 489    02155             Medford     Medford  Middlesex   Metro Boston
# 490    02156        West Medford     Medford  Middlesex   Metro Boston
# 491    02158              Newton      Newton  Middlesex   Metro Boston
# 492    02160              Newton      Newton  Middlesex   Metro Boston
# 493    02161    Newton Highlands      Newton  Middlesex   Metro Boston
# 494    02162              Newton      Newton  Middlesex   Metro Boston
# 496    02164              Newton      Newton  Middlesex   Metro Boston
# 497    02167       Chestnut Hill      Newton  Middlesex   Metro Boston
# 498    02168               Waban      Newton  Middlesex  Metro Boston
# 499    02169              Quincy      Quincy    Norfolk    Metro South
# 500    02170              Quincy      Quincy    Norfolk    Metro South
# 501    02171              Quincy      Quincy    Norfolk   Metro Boston
# 508    02184           Braintree   Braintree    Norfolk    Metro South
# 509    02185           Braintree   Braintree    Norfolk  Metro Boston
# 510    02186              Milton      Milton    Norfolk   Metro Boston
# 511    02187     Milton Village       Milton    Norfolk  Metro Boston
# 535    02238           Cambridge   Cambridge  Middlesex  Metro Boston
# 537    02246           Brookline   Brookline    Norfolk  Metro Boston
# 540    02269              Quincy      Quincy    Norfolk    Metro South
# 597    02445           Brookline   Brookline    Norfolk   Metro Boston
# 598    02446           Brookline   Brookline    Norfolk   Metro Boston
# 599    02447           Brookline   Brookline    Norfolk  Metro Boston
# 605    02456              Newton      Newton  Middlesex  Metro Boston
# 607    02458              Newton      Newton  Middlesex   Metro Boston
# 608    02459       Newton Center      Newton  Middlesex   Metro Boston
# 609    02460         Newtonville      Newton  Middlesex   Metro Boston
# 610    02461    Newton Highlands      Newton  Middlesex   Metro Boston
# 611    02462  Newton Lower Falls      Newton  Middlesex   Metro Boston
# 612    02464  Newton Upper Falls      Newton  Middlesex   Metro Boston
# 613    02465         West Newton      Newton  Middlesex   Metro Boston
# 614    02466          Auburndale      Newton  Middlesex   Metro Boston
# 615    02467       Chestnut Hill   Brookline    Norfolk   Metro Boston
# 618    02468               Waban      Newton  Middlesex   Metro Boston
# 632    02495              Newton      Newton  Middlesex  Metro Boston

# %% [markdown]
# # C. Initial Screening of MBTA Stations

# %% [markdown]
# Now let's load an MBTA station location dataset.
#
# This is a list of MBTA subway stations in Boston and surrounding municipalities with the position information. All stations are operated by the Massachusetts Bay Transportation Authority. This list includes the rapid transit (Blue, Red, and Orange lines) and light rail (Green Line) As of December 2024, the system has 124 stops and stations. The Silver line and bus rapid transit (BRT) stations are not within the scope of discussion because they are operated as part of the MBTA bus system rather than rapid transit (rail).

# %%
file_path = 'https://drive.google.com/uc?export=download&id=1zVBX8nPaoDAf6a1xTg7L43zbuK824L6D'

station_pos = pd.read_csv(file_path)

station_pos
# Out:
#           stop_name parent_station route_id  position_x  position_y
# 0           Airport    place-aport     Blue  -71.030243   42.374374
# 1           Alewife    place-alfcl      Red  -71.142000   42.396400
# 2    Allston Street    place-alsgr    Green  -71.138010   42.348690
# 3      Amory Street    place-amory    Green  -71.114700   42.351000
# 4            Andrew    place-andrw      Red  -71.057120   42.330190
# ..              ...            ...      ...         ...         ...
# 119      Wellington    place-welln   Orange  -71.077096   42.401907
# 120       Wollaston    place-wlsta      Red  -71.019530   42.265638
# 121      Wonderland    place-wondl     Blue  -70.991800   42.413500
# 122     Wood Island    place-wimnl     Blue  -71.023000   42.379700
# 123        Woodland    place-woodl    Green  -71.243611   42.333056
#
# [124 rows x 5 columns]

# %% [markdown]
# Now we can use the geopy library to find ZIP codes based on latitude and longitude, and append the results as a new column zip_code in the station_pos DataFrame. It may takes for a while.

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# Initialize the geolocator
geolocator = Nominatim(user_agent="station_zipcode_locator")

# Add rate limiter to avoid hitting API limits
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# Function to retrieve ZIP code
def get_zip_code(lat, lon):
    try:
        location = geocode((lat, lon), addressdetails=True)
        if location and 'postcode' in location.raw['address']:
            return location.raw['address']['postcode']
        return None
    except Exception as e:
        print(f"Error retrieving ZIP code for coordinates ({lat}, {lon}): {e}")
        return None

# %%
# Add a new column for ZIP codes to the station_pos DataFrame
station_pos['zip_code'] = station_pos.apply(
    lambda row: get_zip_code(row['position_y'], row['position_x']), axis=1
)

station_pos.loc[station_pos['stop_name'] == 'Harvard', 'zip_code'] = '02138'

from IPython.display import display
print("Station Data with ZIP Codes") # Print the name
display(station_pos) # Display the dataframe
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=42.35186&lon=-71.070728&format=json&addressdetails=1
# Station Data with ZIP Codes
#           stop_name parent_station route_id  position_x  position_y zip_code
# 0           Airport    place-aport     Blue  -71.030243   42.374374    02128
# 1           Alewife    place-alfcl      Red  -71.142000   42.396400    02140
# 2    Allston Street    place-alsgr    Green  -71.138010   42.348690    02134
# 3      Amory Street    place-amory    Green  -71.114700   42.351000    02446
# 4            Andrew    place-andrw      Red  -71.057120   42.330190    02127
# ..              ...            ...      ...         ...         ...      ...
# 119      Wellington    place-welln   Orange  -71.077096   42.401907    02145
# 120       Wollaston    place-wlsta      Red  -71.019530   42.265638    02170
# 121      Wonderland    place-wondl     Blue  -70.991800   42.413500    02151
# 122     Wood Island    place-wimnl     Blue  -71.023000   42.379700    02128
# 123        Woodland    place-woodl    Green  -71.243611   42.333056    02481
#
# [124 rows x 6 columns]

# %% [markdown]
# Now we can filter for stations in the zip codes of the Rapid Transit Communities area.

# %%
# Filter stations in Rapid Transit Communities based on ZIP codes
stations_in_rtc = station_pos[station_pos['zip_code'].isin(rtc_data['zip_code'])]

# Remove duplicate stop_name entries, keeping only the first occurrence
stations_in_rtc_unique = stations_in_rtc.drop_duplicates(subset='stop_name', keep='first')

# Get the count of stations in Rapid Transit Communities
stations_in_rtc_count = len(stations_in_rtc)


# Print the row count
print(f"Number of stations in Rapid Transit Communities: {stations_in_rtc_count}")
stations_in_rtc
# Out:
# Number of stations in Rapid Transit Communities: 46
#              stop_name parent_station route_id  position_x  position_y  \
# 1              Alewife    place-alfcl      Red  -71.142000   42.396400
# 3         Amory Street    place-amory    Green  -71.114700   42.351000
# 8             Assembly    place-astao   Orange  -71.077333   42.392356
# 9       Babcock Street    place-babck    Green  -71.119900   42.351600
# 12         Ball Square    place-balsq    Green  -71.111103   42.399983
# 14        Beaconsfield    place-bcnfd    Green  -71.140556   42.335833
# 21           Braintree    place-brntn      Red  -71.001400   42.207400
# 22        Brandon Hall    place-bndhl    Green  -71.128664   42.340071
# 25     Brookline Hills    place-brkhl    Green  -71.126667   42.331389
# 26   Brookline Village    place-bvmnl    Green  -71.116944   42.332500
# 27             Central    place-cntsq      Red  -71.103400   42.365000
# 29       Chestnut Hill    place-chhil    Green  -71.164722   42.326944
# 33    Cleveland Circle    place-clmnl    Green  -71.149000   42.336222
# 35     Coolidge Corner     place-cool    Green  -71.120890   42.342230
# 37               Davis    place-davis      Red  -71.122500   42.396900
# 38           Dean Road    place-denrd    Green  -71.141547   42.337844
# 41     East Somerville    place-esomr    Green  -71.086944   42.379722
# 42               Eliot    place-eliot    Green  -71.216389   42.318889
# 43    Englewood Avenue    place-engav    Green  -71.145357   42.337049
# 44    Fairbanks Street    place-fbkst    Green  -71.131303   42.339472
# 49       Gilman Square    place-gilmn    Green  -71.096770   42.387920
# 54             Harvard    place-harsq      Red  -71.119300   42.373400
# 63         Kendall/MIT    place-knncl      Red  -71.086200   42.362300
# 65         Kent Street    place-kntst    Green  -71.113885   42.344125
# 66            Lechmere     place-lech    Green  -71.076100   42.371250
# 69       Magoun Square    place-mgngl    Green  -71.106592   42.393722
# 70       Malden Center    place-mlmnl   Orange  -71.074349   42.426715
# 73       Medford/Tufts    place-mdftf    Green  -71.117325   42.408153
# 77    Newton Highlands    place-newtn    Green  -71.205556   42.322500
# 78        North Quincy    place-nqncy      Red  -71.030200   42.275800
# 82           Oak Grove    place-ogmnl   Orange  -71.070889   42.436942
# 87              Porter    place-portr      Red  -71.119028   42.388333
# 89        Quincy Adams    place-qamnl      Red  -71.008083   42.232894
# 90       Quincy Center    place-qnctr      Red  -71.005556   42.251944
# 91           Reservoir    place-rsmnl    Green  -71.148056   42.335278
# 92        Revere Beach    place-rbmnl     Blue  -70.992600   42.407800
# 98   Saint Paul Street    place-stpul    Green  -71.116759   42.343366
# 108    Sullivan Square     place-sull   Orange  -71.076970   42.384031
# 109      Summit Avenue    place-sumav    Green  -71.125182   42.340946
# 112      Tappan Street    place-tapst    Green  -71.138705   42.338469
# 114       Union Square    place-unsqu    Green  -71.094292   42.377144
# 115              Waban    place-waban    Green  -71.230556   42.325833
# 117  Washington Square    place-bcnwa    Green  -71.135386   42.339256
# 119         Wellington    place-welln   Orange  -71.077096   42.401907
# 120          Wollaston    place-wlsta      Red  -71.019530   42.265638
# 121         Wonderland    place-wondl     Blue  -70.991800   42.413500
#
#     zip_code
# 1      02140
# 3      02446
# 8      02145
# 9      02446
# 12     02144
# 14     02445
# 21     02184
# 22     02446
# 25     02445
# 26     02445
# 27     02139
# 29     02467
# 33     02447
# 35     02446
# 37     02144
# 38     02447
# 41     02143
# 42     02158
# 43     02447
# 44     02445
# 49     02143
# 54     02138
# 63     02142
# 65     02446
# 66     02141
# 69     02144
# 70     02148
# 73     02144
# 77     02461
# 78     02171
# 82     02148
# 87     02144
# 89     02269
# 90     02169
# 91     02447
# 92     02151
# 98     02446
# 108    02145
# 109    02446
# 112    02447
# 114    02143
# 115    02468
# 117    02445
# 119    02145
# 120    02170
# 121    02151

# %% [markdown]
# Now a total of 45 stations have been selected, which means that the best TOD site will be located in one of these 45 stations. Let's call them **Candidate Stations** and take a quick look of them.

# %%
import folium

from IPython.display import display
# Initialize a map centered around an average latitude and longitude
map_center = [stations_in_rtc['position_y'].mean(), stations_in_rtc['position_x'].mean()]
mymap = folium.Map(location=map_center, zoom_start=12)

# Add station points to the map
for _, row in stations_in_rtc.iterrows():
    folium.Marker(
        location=[row['position_y'], row['position_x']],
        popup=f"Station: {row['stop_name']}<br>ZIP Code: {row['zip_code']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mymap)

# Display the map directly in Colab
display(mymap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81e918aac80ebb013cd3f1594183d3df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81e918aac80ebb013cd3f1594183d3df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81e918aac80ebb013cd3f1594183d3df = L.map(
#                 &quot;map_81e918aac80ebb013cd3f1594183d3df&quot;,
#                 {
#                     center: [42.35147760869566, -71.10517573913042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d78fc23c375bcd17cbb0e990778c45a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d78fc23c375bcd17cbb0e990778c45a8.addTo(map_81e918aac80ebb013cd3f1594183d3df);
#
#
#             var marker_2f36eff41358d339ab813655776ecab1 = L.marker(
#                 [42.3964, -71.142],
#                 {}
#             ).addTo(map_81e918aac80ebb013cd3f1594183d3df);
#
#
#             var icon_bf895a7b3b1e767507a4d2a2ad0a655c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f36eff41358d339ab813655776ecab1.setIcon(icon_bf895a7b3b1e767507a4d2a2ad0a655c);
#
#
#         var popup_3826b23ba66ff14b21410230beec91e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e662fb32e972c9b01b55266876830fcf = $(`&lt;div id=&quot;html_e662fb32e972c9b01b55266876830fcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Alewife&lt;br&gt;ZIP Code: 02140&lt;/div&gt;`)[0];
#                 popup_3826b23ba66ff14b21410230beec91e1.setContent(html_e662fb32e972c9b01b55266876830fcf);
#
#
#
#         marker_2f36eff41358d339ab813655776ecab1.bindPopup(popup_3826b23ba66ff14b21410230beec91e1)
#         ;
#
#
#
#
#             var marker_cf5553a55855c6c63b05c1eebc7074d7 = L.marker(
#                 [42.351, -71.1147],
#                 {}
#             ).addTo(map_81e918aac80ebb013cd3f1594183d3df);
#
#
#             var icon_d976d8dbbf3f00279af7613e33352f8f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf5553a55855c6c63b05c1eebc7074d7.setIcon(icon_d976d8dbbf3f00279af7613e33352f8f);
#
#
#         var popup_282b907da95f1aaf5d8b622a6bd8869e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_caef08b3f88787803df68710123958c8 = $(`&lt;div id=&quot;html_caef08b3f88787803df68710123958c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Amory Street&lt;br&gt;ZIP Code: 02446&lt;/div&gt;`)[0];
#                 popup_282b907da95f1aaf5d8b622a6bd8869e.setContent(html_caef08b3f88787803df68710123958c8);
#
#
#
#         marker_cf5553a55855c6c63b05c1eebc7074d7.bindPopup(popup_282b907da95f1aaf5d8b622a6bd8869e)
#         ;
#
#
#
#
#             var marker_f8c5bea06a5134c547962a1d64233af2 = L.marker(
#                 [42.392356, -71.077333],
#                 {}
#             ).addTo(map_81e918aac80ebb013cd3f1594183d3df);
#
#
#             var icon_091900375151919c1e2f6a3f7b8be7b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8c5bea06a5134c547962a1d64233af2.setIcon(icon_091900375151919c1e2f6a3f7b8be7b1);
#
#
#         var popup_47e4ef228d4aa5363c0a587f7b3c4db9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3b209b684fc0d043c715581dc1b9bbc = $(`&lt;div id=&quot;html_d3b209b684fc0d043c715581dc1b9bbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Assembly&lt;br&gt;ZIP Code: 02145&lt;/div&gt;`)[0];
#                 popup_47e4ef228d4aa5363c0a587f7b3c4db9.setContent(html_d3b209b684fc0d043c715581dc1b9bbc);
#
#
#
#         marker_f8c5bea06a5134c547962a1d64233af2.bindPopup(popup_47e4ef228d4aa5363c0a587f7b3c4db9)
#         ;
#
#
#
#
#             var marker_83b9136ec4e6d405c18928965ac9429d = L.marker(
#                 [42.3516, -71.1199],
#                 {}
#             ).addTo(map_81e918aac80ebb013cd3f1594183d3df);
#
#
#             var icon_658a1330d16bdb1b75edc0b01771a337 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate

# %% [markdown]
# # D. Ridership In Candidate Stations
#
# In this section, we focus on analyzing the ridership patterns across candidate stations and the population proportion within each community that actively uses Rapid Transit. By doing this, we could better understand how much these stations support community mobility and evaluate the broader impact and accessibility of the transit network. These insights will help prioritize locations that align with TOD principles.
#
# Now let's go back to the Rapid Transit Communities (RTC) dataset and take a look at the population of these communities.

# %%
# Ensure the column is numeric (strip any commas if necessary)
rapid_transit_com['2020_Housing_Units'] = rapid_transit_com['2020_Housing_Units'].replace(',', '', regex=True).astype(int)

# Sort the DataFrame by 2020_Housing_Units in descending order
rapid_transit_com_sorted = rapid_transit_com.sort_values(by='2020_Housing_Units', ascending=False)

rapid_transit_com_sorted
# Out:
#       community community_category  2020_Housing_Units  \
# 25    Cambridge      Rapid Transit               53907
# 119      Quincy      Rapid Transit               47009
# 138  Somerville      Rapid Transit               36269
# 103      Newton      Rapid Transit               33320
# 23    Brookline      Rapid Transit               27961
# 79       Malden      Rapid Transit               27721
# 87      Medford      Rapid Transit               25770
# 124      Revere      Rapid Transit               24539
# 41      Everett      Rapid Transit               18208
# 20    Braintree      Rapid Transit               15077
# 30      Chelsea      Rapid Transit               14554
# 96       Milton      Rapid Transit                9844
#
#     minimum_multi_family_unit capacity unit_cpacity_of_total_housing_units  \
# 25                              13,477                                 25%
# 119                             11,752                                 25%
# 138                              9,067                                 25%
# 103                              8,330                                 25%
# 23                               6,990                                 25%
# 79                               6,930                                 25%
# 87                               6,443                                 25%
# 124                              6,135                                 25%
# 41                               4,552                                 25%
# 20                               3,769                                 25%
# 30                               3,639                                 25%
# 96                               2,461                                 25%
#
#     minimum_land_area developable_station_area  \
# 25                 32                    1,392
# 119                50                    1,222
# 138                24                    1,314
# 103                50                    2,833
# 23                 41                    1,349
# 79                 31                      484
# 87                 35                      714
# 124                27                      457
# 41                 22                      200
# 20                 50                      485
# 30                 14                      608
# 96                 50                      404
#
#     percent_of_district_to_be_located_in_station_area
# 25                                                90%
# 119                                               90%
# 138                                               90%
# 103                                               90%
# 23                                                90%
# 79                                                50%
# 87                                                75%
# 124                                               50%
# 41                                                20%
# 20                                                50%
# 30                                                75%
# 96                                                50%

# %% [markdown]
# But these housing unit counts may not directly reflect actual population, so I found the 2020 (most recent) census results for these areas from the Massachusetts Census Data. For details, see: https://malegislature.gov/Redistricting/MassachusettsCensusData/CityTown
#
# Now let's load this dataset and append the population count to the existing data frame.

# %%
file_path = 'https://drive.google.com/uc?export=download&id=1zdhIPijfRCCJBEDG1Vj0WnvfzMDlOS9h'

rtc_census = pd.read_csv(file_path)

# Merge rtc_census into rapid_transit_com_sorted based on the community column
rapid_transit_com_sorted = rapid_transit_com_sorted.merge(
    rtc_census[['community', '2020_census']],
    on='community',
    how='left'
)

# Check if '2020_census' column exists before popping
if '2020_census' in rapid_transit_com_sorted.columns:
    # Insert the 2020_census column at the fourth position
    col_to_insert = rapid_transit_com_sorted.pop('2020_census')  # Remove the column from the DataFrame
    rapid_transit_com_sorted.insert(3, '2020_census', col_to_insert)  # Insert it at the fourth position (index 3)
else:
    print("Column '2020_census' not found in DataFrame after merge. Check your data.")


rapid_transit_com_sorted
# Out:
#      community community_category  2020_Housing_Units  2020_census  \
# 0    Cambridge      Rapid Transit               53907       118403
# 1       Quincy      Rapid Transit               47009       101636
# 2   Somerville      Rapid Transit               36269        81045
# 3       Newton      Rapid Transit               33320        88923
# 4    Brookline      Rapid Transit               27961        63191
# 5       Malden      Rapid Transit               27721        66263
# 6      Medford      Rapid Transit               25770        59659
# 7       Revere      Rapid Transit               24539        62186
# 8      Everett      Rapid Transit               18208        49075
# 9    Braintree      Rapid Transit               15077        39143
# 10     Chelsea      Rapid Transit               14554        40787
# 11      Milton      Rapid Transit                9844        28630
#
#    minimum_multi_family_unit capacity unit_cpacity_of_total_housing_units  \
# 0                              13,477                                 25%
# 1                              11,752                                 25%
# 2                               9,067                                 25%
# 3                               8,330                                 25%
# 4                               6,990                                 25%
# 5                               6,930                                 25%
# 6                               6,443                                 25%
# 7                               6,135                                 25%
# 8                               4,552                                 25%
# 9                               3,769                                 25%
# 10                              3,639                                 25%
# 11                              2,461                                 25%
#
#    minimum_land_area developable_station_area  \
# 0                 32                    1,392
# 1                 50                    1,222
# 2                 24                    1,314
# 3                 50                    2,833
# 4                 41                    1,349
# 5                 31                      484
# 6                 35                      714
# 7                 27                      457
# 8                 22                      200
# 9                 50                      485
# 10                14                      608
# 11                50                      404
#
#    percent_of_district_to_be_located_in_station_area
# 0                                                90%
# 1                                                90%
# 2                                                90%
# 3                                                90%
# 4                                                90%
# 5                                                50%
# 6                                                75%
# 7                                                50%
# 8                                                20%
# 9                                                50%
# 10                                               75%
# 11                                               50%

# %% [markdown]
# ---
#
# Now, let's load the dataset of MBTA rail ridership in Fall 2023.
#
# This file contains detailed ridership data for heavy rail and light rail during the **Fall 2023** rating ***(August 27-December 16, 112 days in total)***. It contains the average ridership for a typical day during the rating by route/line, direction, stop, day type, and SDP (Service Delivery Policy) time period.
#
# For routes with multiple branches, for example the Red Line with Braintree and Ashmont branches, and the Green Line with the B, C, D, and E branches, ridership estimates are combined through the trunk.
#
# We will focus on the following fields:
#
# * **day_type_name**: Text description of the Weekday, Saturday, or Sunday; holidays are excluded from the data
#
#   * For this period, **non-holiday weekdays** were 80 weekdays - 3 holidays (Labor Day, Columbus Day, Thanksgiving) = **77 days**
#
#   * **Saturdays** were **16 days** in total (Veterans Day falls on a Saturday, so no adjustment).
#
#   * **Sunday** were also **16 days** in total.
#
# * **stop_name**: General Transit Feed Specification(GTFS)-compatible stop name for which ridership
#
# * **total_ons**: The count of passengers boarding vehicles.
#
# * **total_offs**: The count of passengers alighting vehicles.
#
# For more information, please check out the link: https://mbta-massdot.opendata.arcgis.com/datasets/MassDOT::fall-2023-mbta-rail-ridership-data-by-sdp-time-period-route-line-and-stop/about

# %%
file_path = 'https://drive.google.com/uc?export=download&id=1qVq6brOcnvJP49UYSgMyJVz7BCYYA3lm'

mbta_rider = pd.read_csv(file_path)

mbta_rider
# Out:
#             mode     season route_id   route_name dir_id  day_type_id  \
# 0     Heavy Rail  Fall 2023     Blue    Blue Line     EB  day_type_01
# 1     Heavy Rail  Fall 2023     Blue    Blue Line     EB  day_type_01
# 2     Heavy Rail  Fall 2023   Orange  Orange Line     NB  day_type_01
# 3     Heavy Rail  Fall 2023     Blue    Blue Line     EB  day_type_01
# 4     Heavy Rail  Fall 2023   Orange  Orange Line     NB  day_type_01
# ...          ...        ...      ...          ...    ...          ...
# 2723  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2724  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2725  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2726  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2727  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
#
#      day_type_name  time_period_id    time_period_name            stop_name  \
# 0          Weekday  time_period_01  VERY_EARLY_MORNING              Airport
# 1          Weekday  time_period_09               NIGHT    Government Center
# 2          Weekday  time_period_02            EARLY_AM          Stony Brook
# 3          Weekday  time_period_01  VERY_EARLY_MORNING             Aquarium
# 4          Weekday  time_period_02            EARLY_AM      Sullivan Square
# ...            ...             ...                 ...                  ...
# 2723       Weekday  time_period_09               NIGHT        Magoun Square
# 2724       Weekday  time_period_09               NIGHT        Medford/Tufts
# 2725       Weekday  time_period_09               NIGHT         Mission Park
# 2726       Weekday  time_period_09               NIGHT  Museum of Fine Arts
# 2727       Weekday  time_period_09               NIGHT        Newton Centre
#
#      parent_station  total_ons  total_offs  number_service_days  average_ons  \
# 0       place-aport       1052        2567                   71           15
# 1       place-gover      24222          51                   71          341
# 2       place-sbmnl       6439         293                   54          119
# 3       place-aqucl        953         560                   71           13
# 4        place-sull       1085        6383                   54           20
# ...             ...        ...         ...                  ...          ...
# 2723    place-mgngl          2           0                   42            0
# 2724    place-mdftf          0           0                   42            0
# 2725    place-mispk          0         418                   42            0
# 2726      place-mfa         12          77                   42            0
# 2727    place-newto          4         135                   42            0
#
#       average_offs  average_flow  ObjectId
# 0               36            82         1
# 1                1           365         2
# 2                5           764         3
# 3                8           145         4
# 4              118           245         5
# ...            ...           ...       ...
# 2723             0             0      2724
# 2724             0             0      2725
# 2725            10            19      2726
# 2726             2            40      2727
# 2727             3            54      2728
#
# [2728 rows x 18 columns]

# %% [markdown]
# Filter the data of 45 candidate stations from this dataset and ignore the others.

# %%
# Extract the list of 45 candidate stations from 'stations_in_rtc' using the 'stop_name' field
candidate_stations = stations_in_rtc['stop_name'].unique()

# Filter the ridership dataset for rows corresponding to candidate stations
candidate_rider = mbta_rider[mbta_rider['stop_name'].isin(candidate_stations)]

candidate_rider
# Out:
#             mode     season route_id   route_name dir_id  day_type_id  \
# 4     Heavy Rail  Fall 2023   Orange  Orange Line     NB  day_type_01
# 8     Heavy Rail  Fall 2023   Orange  Orange Line     NB  day_type_01
# 11    Heavy Rail  Fall 2023   Orange  Orange Line     NB  day_type_01
# 15    Heavy Rail  Fall 2023     Blue    Blue Line     EB  day_type_01
# 18    Heavy Rail  Fall 2023     Blue    Blue Line     EB  day_type_01
# ...          ...        ...      ...          ...    ...          ...
# 2710  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2719  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2720  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2723  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
# 2724  Light Rail  Fall 2023    Green   Green Line     WB  day_type_01
#
#      day_type_name  time_period_id    time_period_name        stop_name  \
# 4          Weekday  time_period_02            EARLY_AM  Sullivan Square
# 8          Weekday  time_period_02            EARLY_AM       Wellington
# 11         Weekday  time_period_03             AM_PEAK         Assembly
# 15         Weekday  time_period_01  VERY_EARLY_MORNING     Revere Beach
# 18         Weekday  time_period_09               NIGHT     Revere Beach
# ...            ...             ...                 ...              ...
# 2710       Weekday  time_period_09               NIGHT    Gilman Square
# 2719       Weekday  time_period_09               NIGHT      Kent Street
# 2720       Weekday  time_period_09               NIGHT         Lechmere
# 2723       Weekday  time_period_09               NIGHT    Magoun Square
# 2724       Weekday  time_period_09               NIGHT    Medford/Tufts
#
#      parent_station  total_ons  total_offs  number_service_days  average_ons  \
# 4        place-sull       1085        6383                   54           20
# 8       place-welln        440        3284                   54            8
# 11      place-astao        643       14684                   54           12
# 15      place-rbmnl         78         591                   71            1
# 18      place-rbmnl        137       12504                   71            2
# ...             ...        ...         ...                  ...          ...
# 2710    place-gilmn         25           0                   42            1
# 2719    place-kntst          0          30                   42            0
# 2720     place-lech         42           2                   42            1
# 2723    place-mgngl          2           0                   42            0
# 2724    place-mdftf          0           0                   42            0
#
#       average_offs  average_flow  ObjectId
# 4              118           245         5
# 8               61           106         9
# 11             272           466        12
# 15               8            17        16
# 18             176           123        19
# ...            ...           ...       ...
# 2710             0             1      2711
# 2719             1            27      2720
# 2720             0             3      2721
# 2723             0             0      2724
# 2724             0             0      2725
#
# [1012 rows x 18 columns]

# %% [markdown]
# The entry and exit data of 45 stations are summed up according to the weekdays, Saturdays and Sundays.

# %%
# Group by 'station_name' and 'day_type' (weekday, saturday, sunday), then sum 'total_ons' and 'total_offs'
aggregated_rider_data = (
    candidate_rider.groupby(['stop_name', 'day_type_name'])[['total_ons', 'total_offs']]
    .sum()
    .reset_index()
)

aggregated_rider_data
# Out:
#         stop_name day_type_name  total_ons  total_offs
# 0         Alewife      Saturday      25245       28240
# 1         Alewife        Sunday      20772       23289
# 2         Alewife       Weekday     235887      267687
# 3    Amory Street      Saturday       2301        1232
# 4    Amory Street        Sunday       2313        1050
# ..            ...           ...        ...         ...
# 133     Wollaston        Sunday       7697        7627
# 134     Wollaston       Weekday     115285      114293
# 135    Wonderland      Saturday      59033       49039
# 136    Wonderland        Sunday      43748       37528
# 137    Wonderland       Weekday     378702      328672
#
# [138 rows x 4 columns]

# %% [markdown]
# Calculate the average passenger flow in three cases and separate them into three dataframes.

# %%
# Define the number of days for each day type
days_count = {'Weekday': 77, 'Saturday': 16, 'Sunday': 16}


# Add average columns for each day type
aggregated_rider_data['avg_ons'] = aggregated_rider_data.apply(
    lambda row: row['total_ons'] / days_count[row['day_type_name']], axis=1
)
aggregated_rider_data['avg_offs'] = aggregated_rider_data.apply(
    lambda row: row['total_offs'] / days_count[row['day_type_name']], axis=1
)

# Format avg_ons and avg_offs to three decimal places
aggregated_rider_data['avg_ons'] = aggregated_rider_data['avg_ons'].round(3)
aggregated_rider_data['avg_offs'] = aggregated_rider_data['avg_offs'].round(3)

# Split the DataFrame based on 'day_type_name'
wkd_rider = aggregated_rider_data[aggregated_rider_data['day_type_name'] == 'Weekday']
sat_rider = aggregated_rider_data[aggregated_rider_data['day_type_name'] == 'Saturday']
sun_rider = aggregated_rider_data[aggregated_rider_data['day_type_name'] == 'Sunday']

# Add a column for total days corresponding to each day type
wkd_rider['total_days'] = days_count['Weekday']
sat_rider['total_days'] = days_count['Saturday']
sun_rider['total_days'] = days_count['Sunday']

# Concatenate all riders into one DataFrame
all_rider = pd.concat([wkd_rider, sat_rider, sun_rider])

# Group by station and calculate the totals and averages
tot_rider = all_rider.groupby('stop_name').apply(
    lambda group: pd.Series({
        'total_ons': group['total_ons'].sum(),
        'total_offs': group['total_offs'].sum(),
        'avg_ons': group['total_ons'].sum() / group['total_days'].sum(),
        'avg_offs': group['total_offs'].sum() / group['total_days'].sum(),
    })
).reset_index()

# Format avg_ons and avg_offs to three decimal places
tot_rider['avg_ons'] = tot_rider['avg_ons'].round(3)
tot_rider['avg_offs'] = tot_rider['avg_offs'].round(3)

# %% [markdown]
# We can generate four interactive bar charts to take a closer look at this data.

# %%
import plotly.graph_objects as go

# Function to plot interactive bar charts with hover and improved proportions
def plot_hover_barchart(df, title):
    # Sort by avg_ons in descending order
    df_sorted = df.sort_values(by='avg_ons', ascending=False)

    # Create bar traces
    fig = go.Figure()

    # Add avg_ons bars
    fig.add_trace(go.Bar(
        x=df_sorted['stop_name'],
        y=df_sorted['avg_ons'],
        name='avg_ons',
        hovertemplate='Station: %{x}<br>avg_ons: %{y:.2f}',
        marker_color='blue',
        width=0.4  # Adjust bar width for better spacing
    ))

    # Add avg_offs bars
    fig.add_trace(go.Bar(
        x=df_sorted['stop_name'],
        y=df_sorted['avg_offs'],
        name='avg_offs',
        hovertemplate='Station: %{x}<br>avg_offs: %{y:.2f}',
        marker_color='orange',
        width=0.4  # Adjust bar width for better spacing
    ))

    # Customize layout for better visibility
    fig.update_layout(
        title=title,
        xaxis_title='Station Name',
        yaxis_title='Average Values',
        barmode='group',
        xaxis_tickangle=45,  # Tilt the labels slightly for better visibility
        legend_title='Metrics',
        height=800,  # Increase chart height
        width=1400,  # Increase chart width
        bargap=0.2,  # Add space between groups of bars
    )

    # Show the interactive plot
    fig.show()

# Plot interactive bar charts for tot_rider, wkd_rider, sat_rider, sun_rider
plot_hover_barchart(tot_rider, 'Total Rider: Average On/Off per Day')
plot_hover_barchart(wkd_rider, 'Weekday Rider: Average On/Off per Day')
plot_hover_barchart(sat_rider, 'Saturday Rider: Average On/Off per Day')
plot_hover_barchart(sun_rider, 'Sunday Rider: Average On/Off per Day')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c10df0f6-b71e-4f5b-b40b-33bbaabd18da" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c10df0f6-b71e-4f5b-b40b-33bbaabd18da")) {                    Plotly.newPlot(                        "c10df0f6-b71e-4f5b-b40b-33bbaabd18da",                        [{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_ons: %{y:.2f}","marker":{"color":"blue"},"name":"avg_ons","width":0.4,"x":["Harvard","Kendall\u002fMIT","Wonderland","Central","Malden Center","Sullivan Square","Revere Beach","Alewife","Assembly","Davis","Oak Grove","Wellington","Porter","Quincy Center","North Quincy","Wollaston","Braintree","Quincy Adams","Coolidge Corner","Medford\u002fTufts","Lechmere","Gilman Square","Union Square","Brookline Village","Washington Square","Babcock Street","Reservoir","Amory Street","Saint Paul Street","Tappan Street","Summit Avenue","Chestnut Hill","Ball Square","Brookline Hills","Newton Highlands","Beaconsfield","Englewood Avenue","Magoun Square","Eliot","Fairbanks Street","Dean Road","Brandon Hall","Cleveland Circle","Kent Street","Waban","East Somerville"],"y":[6041.046,4579.092,4417.275,4065.936,3759.899,3047.954,2645.009,2586.275,2510.853,2428.991,2304.367,2280.908,2248.367,1777.706,1303.358,1227.945,925.55,732.752,633.752,630.303,470.89,373.147,303.339,295.165,257.505,252.119,244.55,239.734,224.771,193.468,189.587,188.982,182.294,174.743,171.11,167.312,163.743,142.569,135.165,127.248,111.193,106.541,103.688,102.174,102.064,58.257],"type":"bar"},{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_offs: %{y:.2f}","marker":{"color":"orange"},"name":"avg_offs","width":0.4,"x":["Harvard","Kendall\u002fMIT","Wonderland","Central","Malden Center","Sullivan Square","Revere Beach","Alewife","Assembly","Davis","Oak Grove","Wellington","Porter","Quincy Center","North Quincy","Wollaston","Braintree","Quincy Adams","Coolidge Corner","Medford\u002fTufts","Lechmere","Gilman Square","Union Square","Brookline Village","Washington Square","Babcock Street","Reservoir","Amory Street","Saint Paul Street","Tappan Street","Summit Avenue","Chestnut Hill","Ball Square","Brookline Hills","Newton Highlands","Beaconsfield","Englewood Avenue","Magoun Square","Eliot","Fairbanks Street","Dean Road","Brandon Hall","Cleveland Circle","Kent Street","Waban","East Somerville"],"y":[6183.339,5138.899,3809.532,4364.67,3781.899,2656.67,2776.431,2928.587,2413.367,2833.018,2605.734,2101.064,2483.881,1588.459,1430.927,1211.45,853.459,774.303,387.101,248.45,538.339,274.055,296.817,261.927,167.422,195.459,218.587,130.936,91.706,121.294,112.505,104.018,153.358,92.009,99.028,93.725,90.642,155.606,65.817,71.11,74.183,52.908,180.239,36.119,59.89,141.156],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cf8f63a8-806e-4554-a273-ecf6fc0daa5e" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf8f63a8-806e-4554-a273-ecf6fc0daa5e")) {                    Plotly.newPlot(                        "cf8f63a8-806e-4554-a273-ecf6fc0daa5e",                        [{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_ons: %{y:.2f}","marker":{"color":"blue"},"name":"avg_ons","width":0.4,"x":["Harvard","Kendall\u002fMIT","Wonderland","Central","Malden Center","Sullivan Square","Alewife","Revere Beach","Davis","Oak Grove","Wellington","Porter","Assembly","Quincy Center","North Quincy","Wollaston","Braintree","Quincy Adams","Medford\u002fTufts","Coolidge Corner","Lechmere","Gilman Square","Union Square","Brookline Village","Washington Square","Reservoir","Amory Street","Babcock Street","Saint Paul Street","Ball Square","Tappan Street","Summit Avenue","Chestnut Hill","Brookline Hills","Newton Highlands","Beaconsfield","Englewood Avenue","Magoun Square","Eliot","Fairbanks Street","Dean Road","Brandon Hall","Waban","Kent Street","Cleveland Circle","East Somerville"],"y":[6601.571,5649.052,4918.208,4608.403,4294.597,3427.208,3063.468,2891.792,2779.779,2718.247,2619.935,2566.0,2466.857,2158.571,1600.221,1497.208,1124.403,902.636,842.584,709.286,608.377,485.442,375.74,343.429,296.571,288.039,279.442,277.584,260.922,227.143,224.26,222.416,220.883,208.247,203.091,197.286,189.727,175.39,158.532,147.649,123.688,123.091,120.623,120.494,118.896,70.208],"type":"bar"},{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_offs: %{y:.2f}","marker":{"color":"orange"},"name":"avg_offs","width":0.4,"x":["Harvard","Kendall\u002fMIT","Wonderland","Central","Malden Center","Sullivan Square","Alewife","Revere Beach","Davis","Oak Grove","Wellington","Porter","Assembly","Quincy Center","North Quincy","Wollaston","Braintree","Quincy Adams","Medford\u002fTufts","Coolidge Corner","Lechmere","Gilman Square","Union Square","Brookline Village","Washington Square","Reservoir","Amory Street","Babcock Street","Saint Paul Street","Ball Square","Tappan Street","Summit Avenue","Chestnut Hill","Brookline Hills","Newton Highlands","Beaconsfield","Englewood Avenue","Magoun Square","Eliot","Fairbanks Street","Dean Road","Brandon Hall","Waban","Kent Street","Cleveland Circle","East Somerville"],"y":[6750.247,6358.727,4268.468,4898.532,4274.39,2947.156,3476.455,2987.701,3222.156,3052.584,2395.104,2822.364,2417.273,1916.61,1781.818,1484.325,1057.571,967.974,287.701,388.61,637.065,313.636,318.909,288.364,182.156,259.675,155.714,211.935,95.104,175.494,140.87,120.623,122.325,105.364,110.857,110.182,96.896,175.675,75.416,80.818,78.727,58.351,72.299,40.662,188.87,166.844],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6be5f4f1-9ca7-424d-abae-0e94f086ba25" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6be5f4f1-9ca7-424d-abae-0e94f086ba25")) {                    Plotly.newPlot(                        "6be5f4f1-9ca7-424d-abae-0e94f086ba25",                        [{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_ons: %{y:.2f}","marker":{"color":"blue"},"name":"avg_ons","width":0.4,"x":["Harvard","Wonderland","Central","Assembly","Malden Center","Sullivan Square","Revere Beach","Kendall\u002fMIT","Davis","Wellington","Porter","Oak Grove","Alewife","Quincy Center","North Quincy","Wollaston","Braintree","Coolidge Corner","Quincy Adams","Babcock Street","Brookline Village","Washington Square","Union Square","Lechmere","Reservoir","Amory Street","Saint Paul Street","Tappan Street","Gilman Square","Chestnut Hill","Medford\u002fTufts","Summit Avenue","Newton Highlands","Brookline Hills","Beaconsfield","Englewood Avenue","Dean Road","Eliot","Ball Square","Fairbanks Street","Brandon Hall","Magoun Square","Cleveland Circle","Waban","Kent Street","East Somerville"],"y":[5258.5,3689.562,3100.875,3034.125,2959.0,2550.062,2317.312,2186.875,1823.812,1780.0,1653.562,1614.875,1577.812,1016.625,679.188,679.0,543.188,460.125,394.125,203.125,186.625,168.25,163.188,146.5,146.438,143.812,133.188,123.75,121.125,116.812,112.062,108.875,103.188,99.562,99.0,98.375,82.0,77.688,77.625,74.812,67.562,66.062,62.062,56.125,53.188,33.125],"type":"bar"},{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_offs: %{y:.2f}","marker":{"color":"orange"},"name":"avg_offs","width":0.4,"x":["Harvard","Wonderland","Central","Assembly","Malden Center","Sullivan Square","Revere Beach","Kendall\u002fMIT","Davis","Wellington","Porter","Oak Grove","Alewife","Quincy Center","North Quincy","Wollaston","Braintree","Coolidge Corner","Quincy Adams","Babcock Street","Brookline Village","Washington Square","Union Square","Lechmere","Reservoir","Amory Street","Saint Paul Street","Tappan Street","Gilman Square","Chestnut Hill","Medford\u002fTufts","Summit Avenue","Newton Highlands","Brookline Hills","Beaconsfield","Englewood Avenue","Dean Road","Eliot","Ball Square","Fairbanks Street","Brandon Hall","Magoun Square","Cleveland Circle","Waban","Kent Street","East Somerville"],"y":[5254.562,3064.938,3421.125,2810.75,3074.625,2310.0,2530.5,2394.625,2130.438,1679.312,1843.188,1853.625,1765.0,933.188,664.875,633.0,431.062,399.312,375.0,164.188,209.188,141.375,282.375,340.125,144.312,77.0,79.625,72.312,205.125,65.938,152.5,88.0,85.375,63.688,55.625,71.688,61.562,47.062,107.062,45.25,43.625,114.25,155.75,26.438,19.5,93.062],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74403340-27d4-42e6-8b43-8a15b55926c0" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74403340-27d4-42e6-8b43-8a15b55926c0")) {                    Plotly.newPlot(                        "74403340-27d4-42e6-8b43-8a15b55926c0",                        [{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_ons: %{y:.2f}","marker":{"color":"blue"},"name":"avg_ons","width":0.4,"x":["Harvard","Wonderland","Central","Assembly","Malden Center","Kendall\u002fMIT","Revere Beach","Sullivan Square","Davis","Porter","Alewife","Wellington","Oak Grove","Quincy Center","North Quincy","Wollaston","Coolidge Corner","Braintree","Quincy Adams","Babcock Street","Brookline Village","Washington Square","Amory Street","Saint Paul Street","Lechmere","Reservoir","Medford\u002fTufts","Tappan Street","Summit Avenue","Chestnut Hill","Englewood Avenue","Union Square","Beaconsfield","Brookline Hills","Newton Highlands","Gilman Square","Fairbanks Street","Dean Road","Eliot","Cleveland Circle","Ball Square","Brandon Hall","Kent Street","Magoun Square","Waban","East Somerville"],"y":[4126.062,2734.25,2420.375,2199.312,1987.562,1822.125,1785.062,1720.688,1346.0,1314.562,1298.25,1150.25,1002.062,705.875,498.875,481.062,443.875,350.938,253.812,178.562,171.438,158.75,144.562,142.375,133.625,133.375,126.938,115.0,112.312,107.625,104.062,95.062,91.375,88.688,85.125,84.75,81.5,80.25,80.188,72.125,71.125,65.875,63.0,61.125,58.688,25.875],"type":"bar"},{"hovertemplate":"Station: %{x}\u003cbr\u003eavg_offs: %{y:.2f}","marker":{"color":"orange"},"name":"avg_offs","width":0.4,"x":["Harvard","Wonderland","Central","Assembly","Malden Center","Kendall\u002fMIT","Revere Beach","Sullivan Square","Davis","Porter","Alewife","Wellington","Oak Grove","Quincy Center","North Quincy","Wollaston","Coolidge Corner","Braintree","Quincy Adams","Babcock Street","Brookline Village","Washington Square","Amory Street","Saint Paul Street","Lechmere","Reservoir","Medford\u002fTufts","Tappan Street","Summit Avenue","Chestnut Hill","Englewood Avenue","Union Square","Beaconsfield","Brookline Hills","Newton Highlands","Gilman Square","Fairbanks Street","Dean Road","Eliot","Cleveland Circle","Ball Square","Brandon Hall","Kent Street","Magoun Square","Waban","East Somerville"],"y":[4383.875,2345.5,2739.0,1997.188,2119.062,2012.75,2005.625,1605.375,1662.875,1495.625,1455.562,1107.75,1207.375,664.5,508.312,476.688,367.625,293.562,241.562,147.438,187.438,122.562,65.625,87.438,261.438,95.125,155.5,76.062,97.938,54.0,79.5,204.938,52.625,56.062,55.75,152.5,50.25,64.938,38.375,163.188,93.125,36.0,30.875,100.375,33.625,65.625],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...

# %% [markdown]
# But there is too much data. Let's extract the top ten sites in each category and see what we can find.

# %%
# !pip install IPython
from IPython.display import display_html
# Out:
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython) (75.1.0)
# Collecting jedi>=0.16 (from IPython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.13)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.5 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2

# %%
# Calculate the average of 'avg_ons' and 'avg_offs' and store it in a new column
tot_rider['avg_flow'] = (tot_rider['avg_ons'] + tot_rider['avg_offs']) / 2  # Changed .loc to []
wkd_rider['avg_flow'] = (wkd_rider['avg_ons'] + wkd_rider['avg_offs']) / 2  # Changed .loc to []
sat_rider['avg_flow'] = (sat_rider['avg_ons'] + sat_rider['avg_offs']) / 2  # Changed .loc to []
sun_rider['avg_flow'] = (sun_rider['avg_ons'] + sun_rider['avg_offs']) / 2  # Changed .loc to []

# Now use 'avg_total' column in nlargest
tot_rider_top10 = tot_rider.nlargest(10, 'avg_flow')
wkd_rider_top10 = wkd_rider.nlargest(10, 'avg_flow')
sat_rider_top10 = sat_rider.nlargest(10, 'avg_flow')
sun_rider_top10 = sun_rider.nlargest(10, 'avg_flow')

# Combine the top 10 data for presentation
top10_summary = {
    'Total Rider': tot_rider_top10[['stop_name', 'avg_flow']],
    'Weekday Rider': wkd_rider_top10[['stop_name', 'avg_flow']],
    'Saturday Rider': sat_rider_top10[['stop_name', 'avg_flow']],
    'Sunday Rider': sun_rider_top10[['stop_name', 'avg_flow']],
}

# Function to display DataFrames side-by-side with custom styling
def display_side_by_side(*args, **kwargs):
    html_str = ''
    for df, caption in zip(args, kwargs.values()):
        # Format 'avg_flow' to 2 decimal places before styling
        df['avg_flow'] = df['avg_flow'].map('{:.2f}'.format)  # Apply formatting here

        # Reset index to 1-10 and remove column name for index
        styled_df = df.style.hide(axis='index').set_caption(caption)
        styled_df = styled_df.set_properties(**{'text-align': 'center'}) # Center align text
        html_str += styled_df.to_html().replace('table', 'table style="display:inline"')
        html_str += '&nbsp;'  # Add some space between the tables
    display_html(html_str, raw=True)

# Display the top 10 data side-by-side with custom styling
display_side_by_side(
    tot_rider_top10[['stop_name', 'avg_flow']],
    wkd_rider_top10[['stop_name', 'avg_flow']],
    sat_rider_top10[['stop_name', 'avg_flow']],
    sun_rider_top10[['stop_name', 'avg_flow']],
    Total_Rider='Total Rider', # Pass captions as keyword arguments
    Weekday_Rider='Weekday Rider',
    Saturday_Rider='Saturday Rider',
    Sunday_Rider='Sunday Rider',
)
# Out:
# <style type="text/css">
# #T_780af_row0_col0, #T_780af_row0_col1, #T_780af_row1_col0, #T_780af_row1_col1, #T_780af_row2_col0, #T_780af_row2_col1, #T_780af_row3_col0, #T_780af_row3_col1, #T_780af_row4_col0, #T_780af_row4_col1, #T_780af_row5_col0, #T_780af_row5_col1, #T_780af_row6_col0, #T_780af_row6_col1, #T_780af_row7_col0, #T_780af_row7_col1, #T_780af_row8_col0, #T_780af_row8_col1, #T_780af_row9_col0, #T_780af_row9_col1 {
#   text-align: center;
# }
# </style>
# <table style="display:inline" id="T_780af">
#   <caption>Total Rider</caption>
#   <thead>
#     <tr>
#       <th id="T_780af_level0_col0" class="col_heading level0 col0" >stop_name</th>
#       <th id="T_780af_level0_col1" class="col_heading level0 col1" >avg_flow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_780af_row0_col0" class="data row0 col0" >Harvard</td>
#       <td id="T_780af_row0_col1" class="data row0 col1" >6112.19</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row1_col0" class="data row1 col0" >Kendall/MIT</td>
#       <td id="T_780af_row1_col1" class="data row1 col1" >4859.00</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row2_col0" class="data row2 col0" >Central</td>
#       <td id="T_780af_row2_col1" class="data row2 col1" >4215.30</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row3_col0" class="data row3 col0" >Wonderland</td>
#       <td id="T_780af_row3_col1" class="data row3 col1" >4113.40</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row4_col0" class="data row4 col0" >Malden Center</td>
#       <td id="T_780af_row4_col1" class="data row4 col1" >3770.90</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row5_col0" class="data row5 col0" >Sullivan Square</td>
#       <td id="T_780af_row5_col1" class="data row5 col1" >2852.31</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row6_col0" class="data row6 col0" >Alewife</td>
#       <td id="T_780af_row6_col1" class="data row6 col1" >2757.43</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row7_col0" class="data row7 col0" >Revere Beach</td>
#       <td id="T_780af_row7_col1" class="data row7 col1" >2710.72</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row8_col0" class="data row8 col0" >Davis</td>
#       <td id="T_780af_row8_col1" class="data row8 col1" >2631.00</td>
#     </tr>
#     <tr>
#       <td id="T_780af_row9_col0" class="data row9 col0" >Assembly</td>
#       <td id="T_780af_row9_col1" class="data row9 col1" >2462.11</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# &nbsp;<style type="text/css">
# #T_fd1df_row0_col0, #T_fd1df_row0_col1, #T_fd1df_row1_col0, #T_fd1df_row1_col1, #T_fd1df_row2_col0, #T_fd1df_row2_col1, #T_fd1df_row3_col0, #T_fd1df_row3_col1, #T_fd1df_row4_col0, #T_fd1df_row4_col1, #T_fd1df_row5_col0, #T_fd1df_row5_col1, #T_fd1df_row6_col0, #T_fd1df_row6_col1, #T_fd1df_row7_col0, #T_fd1df_row7_col1, #T_fd1df_row8_col0, #T_fd1df_row8_col1, #T_fd1df_row9_col0, #T_fd1df_row9_col1 {
#   text-align: center;
# }
# </style>
# <table style="display:inline" id="T_fd1df">
#   <caption>Weekday Rider</caption>
#   <thead>
#     <tr>
#       <th id="T_fd1df_level0_col0" class="col_heading level0 col0" >stop_name</th>
#       <th id="T_fd1df_level0_col1" class="col_heading level0 col1" >avg_flow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd1df_row0_col0" class="data row0 col0" >Harvard</td>
#       <td id="T_fd1df_row0_col1" class="data row0 col1" >6675.91</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row1_col0" class="data row1 col0" >Kendall/MIT</td>
#       <td id="T_fd1df_row1_col1" class="data row1 col1" >6003.89</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row2_col0" class="data row2 col0" >Central</td>
#       <td id="T_fd1df_row2_col1" class="data row2 col1" >4753.47</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row3_col0" class="data row3 col0" >Wonderland</td>
#       <td id="T_fd1df_row3_col1" class="data row3 col1" >4593.34</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row4_col0" class="data row4 col0" >Malden Center</td>
#       <td id="T_fd1df_row4_col1" class="data row4 col1" >4284.49</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row5_col0" class="data row5 col0" >Alewife</td>
#       <td id="T_fd1df_row5_col1" class="data row5 col1" >3269.96</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row6_col0" class="data row6 col0" >Sullivan Square</td>
#       <td id="T_fd1df_row6_col1" class="data row6 col1" >3187.18</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row7_col0" class="data row7 col0" >Davis</td>
#       <td id="T_fd1df_row7_col1" class="data row7 col1" >3000.97</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row8_col0" class="data row8 col0" >Revere Beach</td>
#       <td id="T_fd1df_row8_col1" class="data row8 col1" >2939.75</td>
#     </tr>
#     <tr>
#       <td id="T_fd1df_row9_col0" class="data row9 col0" >Oak Grove</td>
#       <td id="T_fd1df_row9_col1" class="data row9 col1" >2885.42</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# &nbsp;<style type="text/css">
# #T_003dd_row0_col0, #T_003dd_row0_col1, #T_003dd_row1_col0, #T_003dd_row1_col1, #T_003dd_row2_col0, #T_003dd_row2_col1, #T_003dd_row3_col0, #T_003dd_row3_col1, #T_003dd_row4_col0, #T_003dd_row4_col1, #T_003dd_row5_col0, #T_003dd_row5_col1, #T_003dd_row6_col0, #T_003dd_row6_col1, #T_003dd_row7_col0, #T_003dd_row7_col1, #T_003dd_row8_col0, #T_003dd_row8_col1, #T_003dd_row9_col0, #T_003dd_row9_col1 {
#   text-align: center;
# }
# </style>
# <table style="display:inline" id="T_003dd">
#   <caption>Saturday Rider</caption>
#   <thead>
#     <tr>
#       <th id="T_003dd_level0_col0" class="col_heading level0 col0" >stop_name</th>
#       <th id="T_003dd_level0_col1" class="col_heading level0 col1" >avg_flow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_003dd_row0_col0" class="data row0 col0" >Harvard</td>
#       <td id="T_003dd_row0_col1" class="data row0 col1" >5256.53</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row1_col0" class="data row1 col0" >Wonderland</td>
#       <td id="T_003dd_row1_col1" class="data row1 col1" >3377.25</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row2_col0" class="data row2 col0" >Central</td>
#       <td id="T_003dd_row2_col1" class="data row2 col1" >3261.00</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row3_col0" class="data row3 col0" >Malden Center</td>
#       <td id="T_003dd_row3_col1" class="data row3 col1" >3016.81</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row4_col0" class="data row4 col0" >Assembly</td>
#       <td id="T_003dd_row4_col1" class="data row4 col1" >2922.44</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row5_col0" class="data row5 col0" >Sullivan Square</td>
#       <td id="T_003dd_row5_col1" class="data row5 col1" >2430.03</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row6_col0" class="data row6 col0" >Revere Beach</td>
#       <td id="T_003dd_row6_col1" class="data row6 col1" >2423.91</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row7_col0" class="data row7 col0" >Kendall/MIT</td>
#       <td id="T_003dd_row7_col1" class="data row7 col1" >2290.75</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row8_col0" class="data row8 col0" >Davis</td>
#       <td id="T_003dd_row8_col1" class="data row8 col1" >1977.12</td>
#     </tr>
#     <tr>
#       <td id="T_003dd_row9_col0" class="data row9 col0" >Porter</td>
#       <td id="T_003dd_row9_col1" class="data row9 col1" >1748.38</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# &nbsp;<style type="text/css">
# #T_61530_row0_col0, #T_61530_row0_col1, #T_61530_row1_col0, #T_61530_row1_col1, #T_61530_row2_col0, #T_61530_row2_col1, #T_61530_row3_col0, #T_61530_row3_col1, #T_61530_row4_col0, #T_61530_row4_col1, #T_61530_row5_col0, #T_61530_row5_col1, #T_61530_row6_col0, #T_61530_row6_col1, #T_61530_row7_col0, #T_61530_row7_col1, #T_61530_row8_col0, #T_61530_row8_col1, #T_61530_row9_col0, #T_61530_row9_col1 {
#   text-align: center;
# }
# </style>
# <table style="display:inline" id="T_61530">
#   <caption>Sunday Rider</caption>
#   <thead>
#     <tr>
#       <th id="T_61530_level0_col0" class="col_heading level0 col0" >stop_name</th>
#       <th id="T_61530_level0_col1" class="col_heading level0 col1" >avg_flow</th>
#     </tr>
#   </thead>
#   <tbody>

# %% [markdown]
# Based on these four tables, we can divide these stations with the highest passenger flow into the following categories:
#
#
#
# 1.   **All-Stat Goat**
#
#   * Station: **Harvard**
#
#       Harvard consistently leads in ridership across all day types, with the highest average daily flow (6112.19).
#
#       Its dominance on weekdays (6675.91) highlights its role as a critical hub for commuting and educational activities. And its high weekend ridership (5256.53 on Saturday, 4254.97 on Sunday) suggests that the area supports a mix of activities, including education, leisure, and community events.
#
# 2.   **Weekday-Centric Hub**
#
#   * Station: **Kendall/MIT**
#
#       Kendall/MIT shows strong weekday ridership (6003.89), driven by office workers and MIT students. However, its weekend ridership drops significantly (2290.75 on Saturday, 1917.44 on Sunday), indicating limited non-work-related activities.
#
#
#
# 3.   **Weekend-Centric Anchors**
#
#   * Station: **Wonderland, Revere Beach, Assembly, and Porter**
#
#       These stations demonstrate strong weekend ridership, particularly Wonderland and Assembly.
#
# 4.   **Balanced Weekday and Weekend Area**
#
#   * Station: **Central, Malden Center, Sullivan Square, and Davis**
#
#       Central shows consistent ridership across all days, maintaining top 2-8 positions in all categories. Their balanced ridership profiles suggest they can support diverse user groups, from commuters to weekend shoppers and residents.
#
#
# 5.   **Terminal Commuter Hub**
#
#   * Station: **Alewife and Oak Grove**
#
#       Alewife is a terminus of the Red Line with a large park-and-ride facility, attracting weekday commuters driving in from suburbs. Alewife does not appear in the top 10 on Saturdays or Sundays, indicating significantly lower activity during non-workdays. The lack of recreational destinations or retail hubs nearby may be the reason.
#
#       Similar to Alewife, Oak Grove serves suburban commuters as the northern terminus of the Orange Line and does not rank in the top 10 on weekends, indicating limited activity outside of weekday commuting.

# %% [markdown]
# # E. Inbound Rate
# The discussion above primarily focuses on ridership data. Next, we will analyze the metro passenger activity ratio by combining community population numbers with daily entry counts (avg_ons). Communities with higher activity ratios are likely to be more inclined to adopt and benefit from the TOD model.

# %% [markdown]
# Match the community where the site is located based on the postal code.

# %%
# Ensure 'zip_code' is added to tot_rider from stations_in_rtc
if 'zip_code' not in tot_rider.columns:
    tot_rider = tot_rider.merge(
        stations_in_rtc[['stop_name', 'zip_code']],
        on='stop_name',
        how='left'
    )

# Remove rows with missing 'zip_code'
tot_rider = tot_rider.dropna(subset=['zip_code'])

# Merge 'city' from rtc_data into tot_rider based on 'zip_code'
if 'zip_code' in tot_rider.columns and 'zip_code' in rtc_data.columns:
    tot_rider = tot_rider.merge(
        rtc_data[['zip_code', 'city']],
        on='zip_code',
        how='left'
    )

# Remove rows with missing 'city'
tot_rider = tot_rider.dropna(subset=['city'])

# %%
tot_rider
# Out:
#             stop_name  total_ons  total_offs   avg_ons  avg_offs   avg_flow  \
# 0             Alewife   281904.0    319216.0  2586.275  2928.587  2757.4310
# 1        Amory Street    26131.0     14272.0   239.734   130.936   185.3350
# 2            Assembly   273683.0    263057.0  2510.853  2413.367  2462.1100
# 3      Babcock Street    27481.0     21305.0   252.119   195.459   223.7890
# 4         Ball Square    19870.0     16716.0   182.294   153.358   167.8260
# 5        Beaconsfield    18237.0     10216.0   167.312    93.725   130.5185
# 6           Braintree   100885.0     93027.0   925.550   853.459   889.5045
# 7        Brandon Hall    11613.0      5767.0   106.541    52.908    79.7245
# 8     Brookline Hills    19047.0     10029.0   174.743    92.009   133.3760
# 9   Brookline Village    32173.0     28550.0   295.165   261.927   278.5460
# 10            Central   443187.0    475749.0  4065.936  4364.670  4215.3030
# 11      Chestnut Hill    20599.0     11338.0   188.982   104.018   146.5000
# 12   Cleveland Circle    11302.0     19646.0   103.688   180.239   141.9635
# 13    Coolidge Corner    69079.0     42194.0   633.752   387.101   510.4265
# 14              Davis   264760.0    308799.0  2428.991  2833.018  2631.0045
# 15          Dean Road    12120.0      8086.0   111.193    74.183    92.6880
# 16    East Somerville     6350.0     15386.0    58.257   141.156    99.7065
# 17              Eliot    14733.0      7174.0   135.165    65.817   100.4910
# 18   Englewood Avenue    17848.0      9880.0   163.743    90.642   127.1925
# 19   Fairbanks Street    13870.0      7751.0   127.248    71.110    99.1790
# 20      Gilman Square    40673.0     29872.0   373.147   274.055   323.6010
# 21            Harvard   658474.0    673984.0  6041.046  6183.339  6112.1925
# 22        Kendall/MIT   499121.0    560140.0  4579.092  5138.899  4858.9955
# 23        Kent Street    11137.0      3937.0   102.174    36.119    69.1465
# 24           Lechmere    51327.0     58679.0   470.890   538.339   504.6145
# 25      Magoun Square    15540.0     16961.0   142.569   155.606   149.0875
# 26      Malden Center   409829.0    412227.0  3759.899  3781.899  3770.8990
# 27      Medford/Tufts    68703.0     27081.0   630.303   248.450   439.3765
# 28   Newton Highlands    18651.0     10794.0   171.110    99.028   135.0690
# 29       North Quincy   142066.0    155971.0  1303.358  1430.927  1367.1425
# 30          Oak Grove   251176.0    284025.0  2304.367  2605.734  2455.0505
# 31             Porter   245072.0    270743.0  2248.367  2483.881  2366.1240
# 32       Quincy Adams    79870.0     84399.0   732.752   774.303   753.5275
# 33      Quincy Center   193770.0    173142.0  1777.706  1588.459  1683.0825
# 34          Reservoir    26656.0     23826.0   244.550   218.587   231.5685
# 35       Revere Beach   288306.0    302631.0  2645.009  2776.431  2710.7200
# 36  Saint Paul Street    24500.0      9996.0   224.771    91.706   158.2385
# 37    Sullivan Square   332227.0    289577.0  3047.954  2656.670  2852.3120
# 38      Summit Avenue    20665.0     12263.0   189.587   112.505   151.0460
# 39      Tappan Street    21088.0     13221.0   193.468   121.294   157.3810
# 40       Union Square    33064.0     32353.0   303.339   296.817   300.0780
# 41              Waban    11125.0      6528.0   102.064    59.890    80.9770
# 42  Washington Square    28068.0     18249.0   257.505   167.422   212.4635
# 43         Wellington   248619.0    229016.0  2280.908  2101.064  2190.9860
# 44          Wollaston   133846.0    132048.0  1227.945  1211.450  1219.6975
# 45         Wonderland   481483.0    415239.0  4417.275  3809.532  4113.4035
#
#    zip_code        city
# 0     02140   Cambridge
# 1     02446   Brookline
# 2     02145  Somerville
# 3     02446   Brookline
# 4     02144  Somerville
# 5     02445   Brookline
# 6     02184   Braintree
# 7     02446   Brookline
# 8     02445   Brookline
# 9     02445   Brookline
# 10    02139   Cambridge
# 11    02467   Brookline
# 12    02447   Brookline
# 13    02446   Brookline
# 14    02144  Somerville
# 15    02447   Brookline
# 16    02143  Somerville
# 17    02158      Newton
# 18    02447   Brookline
# 19    02445   Brookline
# 20    02143  Somerville
# 21    02138   Cambridge
# 22    02142   Cambridge
# 23    02446   Brookline
# 24    02141   Cambridge
# 25    02144  Somerville
# 26    02148      Malden
# 27    02144  Somerville
# 28    02461      Newton
# 29    02171      Quincy
# 30    02148      Malden
# 31    02144  Somerville
# 32    02269      Quincy
# 33    02169      Quincy
# 34    02447   Brookline
# 35    02151      Revere
# 36    02446   Brookline
# 37    02145  Somerville
# 38    02446   Brookline
# 39    02447   Brookline
# 40    02143  Somerville
# 41    02468      Newton
# 42    02445   Brookline
# 43    02145  Somerville
# 44    02170      Quincy
# 45    02151      Revere

# %% [markdown]
# Sum up all daily average ons within the community.

# %%
# Group by 'city' and calculate the average of 'avg_ons'
city_avg_ons = tot_rider.groupby('city')['avg_ons'].mean().reset_index()

# Rename columns for clarity
city_avg_ons.rename(columns={'avg_ons': 'city_avg_ons'}, inplace=True)

city_avg_ons
# Out:
#          city  city_avg_ons
# 0   Braintree    925.550000
# 1   Brookline    209.793056
# 2   Cambridge   3548.647800
# 3      Malden   3032.133000
# 4      Newton    136.113000
# 5      Quincy   1260.440250
# 6      Revere   3531.142000
# 7  Somerville   1291.543818

# %%
# Create a dictionary to map communities to their 2020 census values
community_census_mapping = rapid_transit_com_sorted.set_index('community')['2020_census'].to_dict()

# Add a new column in city_avg_ons for the percentage calculation
city_avg_ons['avg_ons_percentage'] = city_avg_ons.apply(
    lambda row: '{:.2f}%'.format(
        (row['city_avg_ons'] / community_census_mapping.get(row['city'], float('nan'))) * 100
    ) if row['city'] in community_census_mapping else 'N/A',
    axis=1
)

city_avg_ons
# Out:
#          city  city_avg_ons avg_ons_percentage
# 0   Braintree    925.550000              2.36%
# 1   Brookline    209.793056              0.33%
# 2   Cambridge   3548.647800              3.00%
# 3      Malden   3032.133000              4.58%
# 4      Newton    136.113000              0.15%
# 5      Quincy   1260.440250              1.24%
# 6      Revere   3531.142000              5.68%
# 7  Somerville   1291.543818              1.59%

# %% [markdown]
# Divide the daily average ons in the community by the local population to get the daily average active passenger ratio in the community, and keep the result to two decimal places.

# %%
import matplotlib.pyplot as plt

# Prepare the data for plotting
city_avg_ons_sorted = city_avg_ons[city_avg_ons['avg_ons_percentage'] != 'N/A']  # Exclude rows with 'N/A'
city_avg_ons_sorted['avg_ons_percentage_value'] = city_avg_ons_sorted['avg_ons_percentage'].str.rstrip('%').astype(float)
city_avg_ons_sorted = city_avg_ons_sorted.sort_values(by='avg_ons_percentage_value', ascending=False)

# Plot the bar chart
plt.figure(figsize=(8, 6))
bars = plt.bar(
    city_avg_ons_sorted['city'],
    city_avg_ons_sorted['avg_ons_percentage_value'],
    color='skyblue'
)

# Add data labels on top of each bar
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{bar.get_height():.2f}%",
        ha='center',
        va='bottom',
        fontsize=10
    )

# Customize the plot
plt.title('Community-wise Rapid Transit Avg_ons as Percentage of Risidents (Inbound Rate)', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Avg_ons Percentage (%)', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# This analysis highlights clear disparities in transit reliance among communities. TOD planning should prioritize areas with high transit usage like **Revere** and **Malden**. However, the TOD still could be located in communities with lower usage like **Brookline** and **Newton** to reduce car dependency.

# %% [markdown]
# # F. Coverage
#
# In this section, we will mainly discuss developable_station_area from the dataset of MBTA communities offered by the Executive Office of Housing and Livable Communities of Massachusetts.

# %%
# The 12 communities in the Rapid Transit category
rapid_transit_com
# Out:
#       community community_category  2020_Housing_Units  \
# 20    Braintree      Rapid Transit               15077
# 23    Brookline      Rapid Transit               27961
# 25    Cambridge      Rapid Transit               53907
# 30      Chelsea      Rapid Transit               14554
# 41      Everett      Rapid Transit               18208
# 79       Malden      Rapid Transit               27721
# 87      Medford      Rapid Transit               25770
# 96       Milton      Rapid Transit                9844
# 103      Newton      Rapid Transit               33320
# 119      Quincy      Rapid Transit               47009
# 124      Revere      Rapid Transit               24539
# 138  Somerville      Rapid Transit               36269
#
#     minimum_multi_family_unit capacity unit_cpacity_of_total_housing_units  \
# 20                               3,769                                 25%
# 23                               6,990                                 25%
# 25                              13,477                                 25%
# 30                               3,639                                 25%
# 41                               4,552                                 25%
# 79                               6,930                                 25%
# 87                               6,443                                 25%
# 96                               2,461                                 25%
# 103                              8,330                                 25%
# 119                             11,752                                 25%
# 124                              6,135                                 25%
# 138                              9,067                                 25%
#
#     minimum_land_area developable_station_area  \
# 20                 50                      485
# 23                 41                    1,349
# 25                 32                    1,392
# 30                 14                      608
# 41                 22                      200
# 79                 31                      484
# 87                 35                      714
# 96                 50                      404
# 103                50                    2,833
# 119                50                    1,222
# 124                27                      457
# 138                24                    1,314
#
#     percent_of_district_to_be_located_in_station_area
# 20                                                50%
# 23                                                90%
# 25                                                90%
# 30                                                75%
# 41                                                20%
# 79                                                50%
# 87                                                75%
# 96                                                50%
# 103                                               90%
# 119                                               90%
# 124                                               50%
# 138                                               90%

# %% [markdown]
# Since only eight of the 45 sites above are located in these 12 communities, let's delete the four that are unnecessary.

# %%
# Filter rapid_transit_com to retain only the communities present in city_avg_ons
final_rtc = rapid_transit_com[rapid_transit_com['community'].isin(city_avg_ons['city'])]

final_rtc
# Out:
#       community community_category  2020_Housing_Units  \
# 20    Braintree      Rapid Transit               15077
# 23    Brookline      Rapid Transit               27961
# 25    Cambridge      Rapid Transit               53907
# 79       Malden      Rapid Transit               27721
# 103      Newton      Rapid Transit               33320
# 119      Quincy      Rapid Transit               47009
# 124      Revere      Rapid Transit               24539
# 138  Somerville      Rapid Transit               36269
#
#     minimum_multi_family_unit capacity unit_cpacity_of_total_housing_units  \
# 20                               3,769                                 25%
# 23                               6,990                                 25%
# 25                              13,477                                 25%
# 79                               6,930                                 25%
# 103                              8,330                                 25%
# 119                             11,752                                 25%
# 124                              6,135                                 25%
# 138                              9,067                                 25%
#
#     minimum_land_area developable_station_area  \
# 20                 50                      485
# 23                 41                    1,349
# 25                 32                    1,392
# 79                 31                      484
# 103                50                    2,833
# 119                50                    1,222
# 124                27                      457
# 138                24                    1,314
#
#     percent_of_district_to_be_located_in_station_area
# 20                                                50%
# 23                                                90%
# 25                                                90%
# 79                                                50%
# 103                                               90%
# 119                                               90%
# 124                                               50%
# 138                                               90%

# %%
# Convert 'percent_of_district_to_be_located_in_station_area' from percentage strings to numeric
final_rtc['percent_of_district_to_be_located_in_station_area'] = (
    final_rtc['percent_of_district_to_be_located_in_station_area']
    .str.rstrip('%')  # Remove the '%' symbol
    .astype(float)  # Convert to float
    / 100  # Convert percentage to decimal
)

# %%
import matplotlib.pyplot as plt

# Sort the data by percent_of_district_to_be_located_in_station_area in descending order
final_rtc_sorted = final_rtc.sort_values(by='percent_of_district_to_be_located_in_station_area', ascending=False)

# Plot the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(
    final_rtc_sorted['community'],
    final_rtc_sorted['percent_of_district_to_be_located_in_station_area'],  # Use values as is
    color='skyblue'
)

# Add data labels on top of each bar
for bar, value in zip(bars, final_rtc_sorted['percent_of_district_to_be_located_in_station_area']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{value * 100:.0f}%",
        ha='center',
        va='bottom',
        fontsize=12
    )

# Customize the plot
plt.title('Percent of District to be Located in Station Area by Community (Descending Order)', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Percent of District in Station Area (%)', fontsize=12)
plt.ylim(0, 1.1)  # Ensure y-axis range is appropriate (assuming values are between 0 and 1)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Brookline, Cambridge, Newton, Quincy, Somerville**
#
#   * These communities have 90% of their district area located within the station area, which means these communities are highly accessible in terms of station proximity and ideal for TOD.
#
# **Braintree, Malden, Revere**
#
#   * These communities have 50% of their district area located within the station area. They may have fewer stations or more dispersed development patterns, reducing overall coverage.

# %% [markdown]
# # G. Developable Station Area

# %% [markdown]
# In this section, we will still focus on the MBTA dataset and specifically observe the developable_station_area field.

# %%
# Convert 'developable_station_area' from string with commas to numeric
final_rtc['developable_station_area'] = final_rtc['developable_station_area'].str.replace(',', '').astype(float)

# %%
# Sort the data by 'developable_station_area' in descending order
final_rtc_sorted = final_rtc.sort_values(by='developable_station_area', ascending=False)

# Plot the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(
    final_rtc_sorted['community'],
    final_rtc_sorted['developable_station_area'],
    color='skyblue'
)

# Add data labels on top of each bar
for bar, value in zip(bars, final_rtc_sorted['developable_station_area']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{value:.0f}",  # Display as integer without decimals
        ha='center',
        va='bottom',
        fontsize=12
    )

# Customize the plot
plt.title('Developable Station Area by Community', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Developable Station Area', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# The chart illustrates the relative Developable Station Area for each community. This metric reflects the size of land available for development within a half-mile radius around transit stations, excluding undevelopable land. It serves as an indicator of the development potential near transit hubs.
#
# In this case, **Newton** emerges as the strongest candidate for TOD due to its large area, while **Cambridge, Brookline, and Somerville** also offer strong potential. Smaller areas like **Malden, Revere and Braintree** require more targeted strategies to maximize development impact.

# %% [markdown]
# # H. Community Commercial Land Use

# %% [markdown]
# Understanding the commercial land use in different communities helps evaluate their need for Transit-Oriented Development (TOD) projects. Communities with established commercial centers or business districts may not require new TOD initiatives. In contrast, communities without significant commercial areas might benefit more from TOD projects. These projects can boost local economic activity and improve connectivity. This section examines the current commercial infrastructure in target communities to assesses how their existing land use aligns with TOD goals.

# %% [markdown]
# Now let's load a Zoning Atlas from the Metropolitan Area Planning Council (MAPC). This dataset is a unique resource for land use, development patterns, and development opportunities across the region. It consists of spatial data and associated tabular data for the base zoning districts of the 101 municipalities in the MAPC region.
#
# For more information, please check: https://datacommon.mapc.org/browser/datasets/421

# %%
# !pip install gdown

import gdown

# Download the file from Google Drive
file_id = '1dF2BbI5srJx7RDq91f1MfAlxHUn12toY'  # Extract the file ID from the URL
output_file = 'land_use.csv'
gdown.download(id=file_id, output=output_file, quiet=False)

# Now read the downloaded CSV file, trying different encodings if necessary
try:
    land_use = pd.read_csv(output_file, encoding='utf-8')  # Try default encoding first
except UnicodeDecodeError:
    land_use = pd.read_csv(output_file, encoding='latin-1')  # Try 'latin-1' if 'utf-8' fails
    # You may need to experiment with other encodings like 'cp1252', 'ISO-8859-1', etc.
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1dF2BbI5srJx7RDq91f1MfAlxHUn12toY
# To: /content/land_use.csv
# 100%|██████████| 705k/705k [00:00<00:00, 11.5MB/s]

# %%
# Print the header (column names)
print(land_use.columns)
# Out:
# Index(['Unnamed: 0', 'objectid', 'muni_id', 'muni', 'zo_code', 'zo_name',
#        'zo_usety', 'zo_abbr', 'zo_usede', 'mf_notes', 'mulfam2', 'mulfam3_4',
#        'mulfam5_19', 'mulfam20_', 'minlotsize', 'mnls_ove', 'mnls_oven',
#        'mnls_calc', 'mnls_eff', 'mnls_notes', 'pctlotcov', 'plc_spec',
#        'plc_ove', 'plc_oven', 'plc_calc', 'plc_eff', 'plc_notes', 'plc_esval',
#        'lapdu', 'lapdu_note', 'lapdu_spec', 'maxflrs', 'mxfl_spec',
#        'mxfl_calc', 'mxfl_eff', 'mxfl_esval', 'maxheight', 'mxht_spec',
#        'mxht_calc', 'mxht_eff', 'mxht_notes', 'maxdu', 'mxdu_spec', 'mxdu_ove',
#        'mxdu_oven', 'mxdu_calc1', 'sfpdu', 'mxdu_calc2', 'mxdu_calc3',
#        'mxdu_eff', 'mxdu_notes', 'mxdu_esval', 'dupac', 'dupac_spec',
#        'dupac_ove', 'dupac_oven', 'dupac_calc1', 'dupac_calc2', 'dupac_calc3',
#        'dupac_eff', 'dupac_notes', 'dupac_esval', 'far', 'far_spec', 'far_ove',
#        'far_oven', 'far_calc', 'far_eff', 'far_esval', 'far_notes', 'far_ques',
#        'createdby', 'createddate', 'editedby', 'mxht_esval', 'mnls_esval',
#        'mnls_spec', 'spatialrec'],
#       dtype='object')

# %% [markdown]
# In this dataset, we will focus on the following fields:
#
# * **muni**: Corresponds to the city or community field in the previous dataset.
#
# * **zo_usede**: Zone Use Description
#
# First, let's start cleaning the data and pick up the land use information of these eight candidate communities.

# %%
# Filter the land_use dataset to keep rows where the 'muni' field matches 'community' in final_rtc
rtc_land_use = land_use[land_use['muni'].isin(final_rtc['community'])]

# Convert the 'zo_usede' column to lowercase for case-insensitive matching
rtc_land_use['zo_usede'] = rtc_land_use['zo_usede'].str.lower()

# Display the filtered dataset to confirm the filtering process
rtc_land_use
# Out:
#       Unnamed: 0  objectid  muni_id       muni      zo_code  \
# 27            28      1426      207     Newton       207BU1
# 29            30      1436      207     Newton        207LM
# 30            31      1458      207     Newton       207SR3
# 70            71      1989       40  Braintree         40GB
# 71            72      1993       46  Brookline  46L-0.5(CL)
# ...          ...       ...      ...        ...          ...
# 1675        1676      2051       49  Cambridge        49O-1
# 1676        1677      2052       49  Cambridge        49O-2
# 1677        1678      2054       49  Cambridge      49SD-4A
# 1729        1730      2114      165     Malden       165RQ3
# 1768        1769      2168      165     Malden       165RQ1
#
#                                                 zo_name  zo_usety    zo_abbr  \
# 27                                           Business 1       2.0        BU1
# 29                                  Light manufacturing       2.0         LM
# 30                                   Single Residence 3       1.0        SR3
# 70                                     General Business       2.0         GB
# 71                                                            3.0  L-0.5(CL)
# ...                                                 ...       ...        ...
# 1675  residential, most institutional, office and la...       3.0        O-1
# 1676  residential, most institutional, office and la...       3.0        O-2
# 1677                      similar to O2 with exceptions       3.0      SD-4A
# 1729  Rowe's Quarry Reclamation and Redevelopment Di...       3.0        RQ3
# 1768  Rowe's Quarry Reclamation and Redevelopment Di...       3.0        RQ1
#
#                                                zo_usede        mf_notes  ...  \
# 27    office, bank. retail, theater, restaurant with...             NaN  ...
# 29                                  light manufacturing             NaN  ...
# 30                                  one family dwelling  MF not allowed  ...
# 70                                                  NaN             NaN  ...
# 71                                                  NaN             NaN  ...
# ...                                                 ...             ...  ...
# 1675                                       multi family             NaN  ...
# 1676                                       multi family             NaN  ...
# 1677                                       multi family             NaN  ...
# 1729                                          mixed use             NaN  ...
# 1768                                          mixed use             NaN  ...
#
#       far_esval                                         far_notes  \
# 27            0                          FAR_NOTES:\r\nFAR_XCEPT:
# 29            1                          FAR_NOTES:\r\nFAR_XCEPT:
# 30            0                          FAR_NOTES:\r\nFAR_XCEPT:
# 70            1                         FAR_NOTES:\r\nFAR_XCEPT:
# 71            0                          FAR_NOTES:\r\nFAR_XCEPT:
# ...         ...                                               ...
# 1675          1                          FAR_NOTES:\r\nFAR_XCEPT:
# 1676          1  FAR_NOTES:1.50 nonresidential uses\r\nFAR_XCEPT:
# 1677          0                          FAR_NOTES:\r\nFAR_XCEPT:
# 1729          1                         FAR_NOTES:\r\nFAR_XCEPT:
# 1768          1                         FAR_NOTES:\r\nFAR_XCEPT:
#
#               far_ques         createdby        createddate  \
# 27     James Armstrong  2/24/2020 7:06pm  Lily Perkins-High
# 29     James Armstrong  2/24/2020 7:06pm  Lily Perkins-High
# 30     James Armstrong  2/24/2020 7:06pm                NaN
# 70    Nina Mascarenhas  7/1/2019 12:00am  Lily Perkins-High
# 71                 NaN               NaN  Lily Perkins-High
# ...                ...               ...                ...
# 1675   James Armstrong  2/24/2020 7:06pm  Lily Perkins-High
# 1676   James Armstrong  2/24/2020 7:06pm  Lily Perkins-High
# 1677   James Armstrong  2/24/2020 7:06pm  Lily Perkins-High
# 1729  Nina Mascarenhas  8/1/2019 12:00am  Lily Perkins-High
# 1768  Nina Mascarenhas  8/1/2019 12:00am  Lily Perkins-High
#
#                 editedby  mxht_esval  mnls_esval  mnls_spec spatialrec
# 27    12/11/2020 12:11pm         0.0           0        NaN   2013/3/1
# 29    12/11/2020 10:45am         0.0           0        NaN   2013/3/1
# 30       3/3/2020 8:38pm         0.0           0        NaN   2013/3/1
# 70      12/8/2020 5:15pm         0.0           0        NaN   2019/5/1
# 71     12/8/2020 11:54am         0.0         NaN        0.0  2012/12/1
# ...                  ...         ...         ...        ...        ...
# 1675    12/2/2020 5:04pm         0.0           0        NaN   2013/4/1
# 1676    12/2/2020 5:04pm         0.0           0        NaN   2013/4/1
# 1677    12/2/2020 5:04pm         0.0           0        NaN   2013/4/1
# 1729    12/8/2020 4:12pm         0.0           0        NaN   1999/1/1
# 1768   12/8/2020 10:16am         0.0           0        NaN   1999/1/1
#
# [169 rows x 78 columns]

# %% [markdown]
# Define a list of keywords related to TOD services and filter out commercial land in these communities.

# %%
# Define a list of keywords related to TOD services
tod_keywords = [
    'commercial', 'retail', 'restaurant', 'theater', 'office', 'shopping',
    'mixed-use', 'mixed use', 'cafe', 'grocery', 'store', 'mall', 'transit', 'parking',
    'recreation', 'cinema', 'park', 'fitness', 'leisure', 'healthcare',
    'museum', 'education', 'library', 'school', 'terminal', 'station'
]

# Clean the 'zo_usede' column to remove extra spaces
rtc_land_use['zo_usede_clean'] = rtc_land_use['zo_usede'].str.strip()

# Filter rows where the cleaned 'zo_usede' contains any TOD-related keywords
rtc_cmt_land_use = rtc_land_use[
    rtc_land_use['zo_usede_clean'].str.contains('|'.join(tod_keywords), na=False)
]

rtc_cmt_land_use
# Out:
#       Unnamed: 0  objectid  muni_id        muni      zo_code  \
# 27            28      1426      207      Newton       207BU1
# 76            77      2053       49   Cambridge         49OS
# 915          916      1249      165      Malden         165I
# 936          937      1265      165      Malden       165RQ2
# 1011        1012      1420      248      Revere     248PDD-2
# 1104        1105      1435      207      Newton       207BU5
# 1111        1112      1451      207      Newton       207MU2
# 1112        1113      1453      207      Newton       207ORD
# 1113        1114      1454      207      Newton       207PUB
# 1124        1125      1457      207      Newton       207MU1
# 1131        1132      1524      248      Revere     248PDD-1
# 1198        1199      1533      243      Quincy        243OS
# 1199        1200      1534      243      Quincy       243PUD
# 1201        1202      1652      274  Somerville       274MR4
# 1205        1206      1658      274  Somerville        274PS
# 1215        1216      1549      248      Revere        248CB
# 1219        1220      1553      248      Revere        248GB
# 1220        1221      1554      248      Revere        248HB
# 1222        1223      1556      248      Revere       248TED
# 1319        1320      1660      274  Somerville       274CC5
# 1321        1322      1661      274  Somerville        274CB
# 1322        1323      1662      274  Somerville       274CC3
# 1323        1324      1663      274  Somerville        274UR
# 1328        1329      1667      274  Somerville       274CC4
# 1401        1402      1749       46   Brookline  46O-2.0(CH)
# 1729        1730      2114      165      Malden       165RQ3
# 1768        1769      2168      165      Malden       165RQ1
#
#                                                 zo_name  zo_usety    zo_abbr  \
# 27                                           Business 1       2.0        BU1
# 76                                  Open Space District       4.0         OS
# 915                                          Industrial       2.0          I
# 936   Rowe's Quarry Reclamation and Redevelopment Di...       3.0        RQ2
# 1011                     Planned Development District 2       2.0      PDD-2
# 1104                                         Business 5       2.0        BU5
# 1111                                        Mixed Use 2       1.0        MU2
# 1112                              Open Space/Recreation       4.0        ORD
# 1113                                         Public Use       4.0        PUB
# 1124                                        Mixed Use 1       1.0        MU1
# 1131                     Planned Development District 1       2.0      PDD-1
# 1198                                         Open Space       4.0         OS
# 1199                           Planned Unit Development       3.0        PUD
# 1201                                   Mid Rise 4 Story       3.0        MR4
# 1205                                 Powderhouse School       3.0         PS
# 1215                                   Central Business       3.0         CB
# 1219          General business and professional offices       3.0         GB
# 1220                                   Highway Business       3.0         HB
# 1222  Research and development, biotechnology, offic...       2.0        TED
# 1319                            Core Commercial 5 Story       2.0        CC5
# 1321                                Commercial Business       2.0         CB
# 1322                            Core Commercial 3 Story       2.0        CC3
# 1323                                   Urban Resdential       1.0         UR
# 1328                            Core Commercial 4 Story       2.0        CC4
# 1401                     Business & Professional Office       2.0  O-2.0(CH)
# 1729  Rowe's Quarry Reclamation and Redevelopment Di...       3.0        RQ3
# 1768  Rowe's Quarry Reclamation and Redevelopment Di...       3.0        RQ1
#
#                                                zo_usede mf_notes  ...  \
# 27    office, bank. retail, theater, restaurant with...      NaN  ...
# 76    public parks, recreation facilities, other pub...      NaN  ...
# 915                                commercial - offices      NaN  ...
# 936                                           mixed use      NaN  ...
# 1011  office, bank, restaurant,retail sales and serv...      NaN  ...
# 1104                                       office, bank      NaN  ...
# 1111                                         mixed uses      NaN  ...
# 1112                          recreation, municipal use      NaN  ...
# 1113                          recreation, municipal use      NaN  ...
# 1124                                         mixed uses      NaN  ...
# 1131  office, bank, restaurant,retail sales and serv...      NaN  ...
# 1198         public parks and playgrounds, conservation      NaN  ...
# 1199                                         mixed uses      NaN  ...
# 1201                municipal and non-profit recreation      NaN  ...
# 1205  institutional, recreational, offices, business...      NaN  ...
# 1215                               community commercial      NaN  ...
# 1219          general business and professional offices      NaN  ...
# 1220         highway commercial and regional businesses      NaN  ...
# 1222  research and development, biotechnology, offic...      NaN  ...
# 1319  office, retail, restaurant, residential, hotel...      NaN  ...
# 1321  office, retail, restaurant, residential, hotel...      NaN  ...
# 1322  office, retail, restaurant, residential, hotel...      NaN  ...
# 1323  institutional, recreational, offices, business...      NaN  ...
# 1328  office, retail, restaurant, residential, hotel...      NaN  ...
# 1401     business & professional office and multifamily      NaN  ...
# 1729                                          mixed use      NaN  ...
# 1768                                          mixed use      NaN  ...
#
#                                               far_notes          far_ques  \
# 27                             FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 76                             FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 915                           FAR_NOTES:\r\nFAR_XCEPT:   Nina Mascarenhas
# 936                           FAR_NOTES:\r\nFAR_XCEPT:   Nina Mascarenhas
# 1011  FAR_NOTES:\r\nFAR_XCEPT:Setback requirements d...   James Armstrong
# 1104                           FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 1111            FAR_NOTES:2.00 by SP.\r\n\r\nFAR_XCEPT:   James Armstrong
# 1112                           FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 1113                           FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 1124            FAR_NOTES:2.00 by SP.\r\n\r\nFAR_XCEPT:   James Armstrong
# 1131                          FAR_NOTES:\r\nFAR_XCEPT:    James Armstrong
# 1198                           FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 1199                           FAR_NOTES:\r\nFAR_XCEPT:   James Armstrong
# 1201                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1205                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1215                          FAR_NOTES:\r\nFAR_XCEPT:    James Armstrong
# 1219                          FAR_NOTES:\r\nFAR_XCEPT:    James Armstrong
# 1220                          FAR_NOTES:\r\nFAR_XCEPT:    James Armstrong
# 1222                          FAR_NOTES:\r\nFAR_XCEPT:    James Armstrong
# 1319                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1321                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1322                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1323                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1328                           FAR_NOTES:\r\nFAR_XCEPT:               NaN
# 1401  FAR_NOTES:1 - 2.5 BASED ON PUB BEN & PROXIMITY...   James Armstrong
# 1729                          FAR_NOTES:\r\nFAR_XCEPT:   Nina Mascarenhas
# 1768                          FAR_NOTES:\r\nFAR_XCEPT:   Nina Mascarenhas
#
#               createdby        createddate            editedby  mxht_esval  \
# 27     2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 12:11pm         0.0
# 76     2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 10:49am         0.0
# 915    8/1/2019 12:00am  Lily Perkins-High    12/8/2020 5:15pm         0.0
# 936    8/1/2019 12:00am  Lily Perkins-High   12/8/2020 10:16am         0.0
# 1011  12/3/2019 12:00am  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1104   2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1111   2/24/2020 7:06pm  Lily Perkins-High    12/8/2020 4:11pm         0.0
# 1112   2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 10:49am         NaN
# 1113   2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 10:49am         NaN
# 1124   2/24/2020 7:06pm  Lily Perkins-High    12/8/2020 4:11pm         0.0
# 1131  12/3/2019 12:00am  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1198   2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 10:49am         NaN
# 1199   2/24/2020 7:06pm  Lily Perkins-High    12/2/2020 5:04pm         1.0
# 1201                NaN  Lily Perkins-High    12/2/2020 1:56pm         0.0
# 1205                NaN  Lily Perkins-High    12/2/2020 5:04pm         0.0
# 1215  12/3/2019 12:00am  Lily Perkins-High    12/8/2020 8:56am         0.0
# 1219  12/3/2019 12:00am  Lily Perkins-High    12/2/2020 4:32pm         0.0
# 1220  12/3/2019 12:00am  Lily Perkins-High    12/2/2020 4:32pm         0.0
# 1222  12/3/2019 12:00am  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1319                NaN  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1321                NaN  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1322                NaN  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1323                NaN  Lily Perkins-High    12/2/2020 5:04pm         0.0
# 1328                NaN  Lily Perkins-High  12/11/2020 10:45am         0.0
# 1401   2/24/2020 7:06pm  Lily Perkins-High  12/11/2020 11:34am         0.0
# 1729   8/1/2019 12:00am  Lily Perkins-High    12/8/2020 4:12pm         0.0
# 1768   8/1/2019 12:00am  Lily Perkins-High   12/8/2020 10:16am         0.0
#
#       mnls_esval  mnls_spec  spatialrec  \
# 27             0        NaN    2013/3/1
# 76             0        NaN    2013/4/1
# 915            0        NaN    1999/1/1
# 936            0        NaN    1999/1/1
# 1011           0        NaN    1999/1/1
# 1104           0        NaN    2013/3/1
# 1111           0        NaN    2013/3/1
# 1112         NaN      999.0    2013/3/1
# 1113         NaN      999.0    2013/3/1
# 1124           0        NaN    2013/3/1
# 1131           0        NaN    1999/1/1
# 1198         NaN      999.0    2013/2/1
# 1199           0        NaN    2013/2/1
# 1201           0        NaN   2019/12/1
# 1205           0        NaN   2019/12/1
# 1215           0        NaN    1999/1/1
# 1219           0        NaN    1999/1/1
# 1220           0        NaN    1999/1/1
# 1222           0        NaN    1999/1/1
# 1319           0        NaN   2019/12/1
# 1321           0        NaN   2019/12/1
# 1322           0        NaN   2019/12/1
# 1323           0        NaN   2019/12/1
# 1328           0        NaN   2019/12/1
# 1401           0        NaN   2012/12/1
# 1729           0        NaN    1999/1/1
# 1768           0        NaN    1999/1/1
#
#                                          zo_usede_clean
# 27    office, bank. retail, theater, restaurant with...
# 76    public parks, recreation facilities, other pub...
# 915                                commercial - offices
# 936                                           mixed use
# 1011  office, bank, restaurant,retail sales and serv...
# 1104                                       office, bank
# 1111                                         mixed uses
# 1112                          recreation, municipal use
# 1113                          recreation, municipal use
# 1124                                         mixed uses
# 1131  office, bank, restaurant,retail sales and serv...
# 1198         public parks and playgrounds, conservation
# 1199                                         mixed uses
# 1201                municipal and non-profit recreation
# 1205  institutional, recreational, offices, business...
# 1215                               community commercial
# 1219          general business and professional offices
# 1220         highway commercial and regional businesses
# 1222  research and development, biotechnology, offic...
# 1319  office, retail, restaurant, residential, hotel...
# 1321  office, retail, restaurant, residential, hotel...
# 1322  office, retail, restaurant, residential, hotel...
# 1323  institutional, recreational, offices, business...
# 1328  office, retail, restaurant, residential, hotel...
# 1401     business & professional office and multifamily
# 1729                                          mixed use
# 1768                                          mixed use
#
# [27 rows x 79 columns]

# %% [markdown]
# Classify and count according to the community name of muni. Then plot the bar chart.

# %%
# Group the filtered land use data by 'muni' and count the number of entries for each community
community_land_use_count = rtc_cmt_land_use.groupby('muni').size().reset_index(name='count')

# Add a new row for Braintree with a count of 0
new_row = pd.DataFrame([{'muni': 'Braintree', 'count': 0}]) # Convert new_row to a DataFrame
community_land_use_count = pd.concat([community_land_use_count, new_row], ignore_index=True)

# Sort the data by count in descending order
community_land_use_count_sorted = community_land_use_count.sort_values(by='count', ascending=False)

# Plot the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(
    community_land_use_count_sorted['muni'],
    community_land_use_count_sorted['count'],
    color='skyblue'
)

# Add data labels on top of each bar
for bar, value in zip(bars, community_land_use_count_sorted['count']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{value}",
        ha='center',
        va='bottom',
        fontsize=12
    )

# Customize the plot
plt.title('Count of TOD-related Land Use by Community', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Count of Land Use Entries', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **High Land Use For Commercial**: Somerville, Newton, and Revere
#
# * These communities may not require new TOD initiatives to create commercial opportunities but could focus on refining existing infrastructure.
#
# **Moderate Land Use For Commercial**: Malden
#
# * 4 TOD-related entries indicate that while Malden has some TOD-aligned land use, there may be gaps in its commercial ecosystem.
#
# **Limited Land Use For Commercial**: Quincy, Brookline, and Cambridge
#
# * Cambridge, Brookline and Quincy might benefit significantly from TOD initiatives, as these projects can create new economic hubs and address gaps in commercial infrastructure.

# %% [markdown]
# # I. Community Land Price

# %% [markdown]
# This section looks at the average land prices in the eight communities being considered for Transit-Oriented Development (TOD) projects. Land prices play an important role in TOD planning. Lower prices can help reduce development costs and make projects more affordable. The analysis of average land prices will help identify areas where TOD projects can be cost-effective.

# %% [markdown]
# Now let's load an innovative dataset from the Metropolitan Area Planning Council (MAPC), called Rethinking the Retail Strip Sites. This dataset This dataset contains almost all the attributes needed to consider a community.
#
# For more information, please check: https://datacommon.mapc.org/browser/datasets/442

# %%
file_path = 'https://drive.google.com/uc?export=download&id=1MYudONECm3oaNcva1Po8CqbXlLplnUDO'

land_price = pd.read_csv(file_path)

land_price
# Out:
#       objectid  site_oid  muni_id   municipal  type_id  subtype_id  \
# 0            1    9475.0     49.0  Somerville    378.0       382.0
# 1            2    9577.0    274.0  Somerville    378.0       382.0
# 2            3    9967.0    274.0  Somerville    378.0       382.0
# 3            4    9695.0    274.0  Somerville    378.0       382.0
# 4            5    9766.0    274.0  Somerville    378.0       382.0
# ...        ...       ...      ...         ...      ...         ...
# 3023      3024   12984.0    320.0      Wenham    377.0       387.0
# 3024      3025   13021.0    320.0      Wenham    377.0       387.0
# 3025      3026   10806.0    196.0      Nahant    379.0       385.0
# 3026      3027    6605.0     78.0       Dover    377.0       388.0
# 3027      3028    6637.0     78.0       Dover    377.0       388.0
#
#                 commtype            county                      subregion  \
# 0             Inner Core  Middlesex County     Inner Core (ICC) Subregion
# 1             Inner Core  Middlesex County     Inner Core (ICC) Subregion
# 2             Inner Core  Middlesex County     Inner Core (ICC) Subregion
# 3             Inner Core  Middlesex County     Inner Core (ICC) Subregion
# 4             Inner Core  Middlesex County     Inner Core (ICC) Subregion
# ...                  ...               ...                            ...
# 3023  Developing Suburbs      Essex County   North Shore (NSTF) Subregion
# 3024  Developing Suburbs      Essex County   North Shore (NSTF) Subregion
# 3025    Maturing Suburbs      Essex County   North Shore (NSTF) Subregion
# 3026  Developing Suburbs    Norfolk County  Three Rivers (TRIC) Subregion
# 3027  Developing Suburbs    Norfolk County  Three Rivers (TRIC) Subregion
#
#       hsubmkt  ... scrcat  taxrevchg munirank regirank munpctile munqntile  \
# 0         2.0  ...    5.0  1184908.0      1.0      1.0     100.0       5.0
# 1         2.0  ...    5.0  1905168.0      1.0      6.0     100.0       5.0
# 2         3.0  ...    5.0   599551.0      2.0      7.0      98.6       5.0
# 3         3.0  ...    5.0  1118084.0      3.0     15.0      97.2       5.0
# 4         3.0  ...    5.0   485416.0      4.0     17.0      95.8       5.0
# ...       ...  ...    ...        ...      ...      ...       ...       ...
# 3023      7.0  ...    1.0   135952.0      2.0   2577.0      50.0       3.0
# 3024      7.0  ...    1.0   216949.0      1.0   2566.0     100.0       5.0
# 3025      4.0  ...    1.0    33470.0      1.0   2895.0     100.0       5.0
# 3026      5.0  ...    1.0    63890.0      1.0   2947.0     100.0       5.0
# 3027      5.0  ...    1.0    74780.0      2.0   2995.0      50.0       3.0
#
#      regipctile       long        lat  \
# 0         100.0 -71.084971  42.374034
# 1          99.8 -71.090362  42.376772
# 2          99.8 -71.085252  42.390996
# 3          99.5 -71.101573  42.381000
# 4          99.5 -71.111849  42.383450
# ...         ...        ...        ...
# 3023       15.1 -70.888122  42.597461
# 3024       15.4 -70.917026  42.602256
# 3025        4.6 -70.936392  42.436704
# 3026        2.9 -71.282641  42.243959
# 3027        1.3 -71.282131  42.244579
#
#                                                   shape
# 0     E60200007D000000080010006A6900008A0B0000011000...
# 1     310100002F000000080010006A69000095040000011000...
# 2     8800000011000000080010006A690000AC010000011000...
# 3     BD0000001B000000080010006A690000A1020000011000...
# 4     700000000D000000080010006A69000094010000011000...
# ...                                                 ...
# 3023  4600000006000000080010006A6900002A010000011000...
# 3024  4600000006000000080010006A6900002A010000011000...
# 3025  9700000014000000080010006A690000BB010000011000...
# 3026  720000000E000000080010006A69000096010000011000...
# 3027  8700000013000000080010006A690000AB010000011000...
#
# [3028 rows x 64 columns]

# %% [markdown]
# In this dataset, we will focus on the following fields:
#
# * **municipal**: Corresponds to the city or community field in the previous dataset.
#
# * **land_value**: Site Assessed Land Value in USD (Combined assessed land value of all parcels in site, ***not including the building***).
#
# * **sitearea_a**: Site area (in acres)
#
# For the specific meaning of other fields, you can refer to: https://drive.google.com/file/d/1rM8krcSvIcjC2WK1Gn5_CvxphwKUJkn0/view?usp=sharing
#
# Now, let's start cleaning the data and pick up the land price information of these eight candidate communities.

# %%
final_rtc_temp = final_rtc.copy()

# Normalize both columns to lowercase and strip whitespace
final_rtc_temp['community'] = final_rtc_temp['community'].str.lower().str.strip()
land_price['municipal'] = land_price['municipal'].str.lower().str.strip()

# Filter the dataset where municipal matches community
rtc_land_price = land_price[land_price['municipal'].isin(final_rtc_temp['community'])]

# Filter rtc_land_price to keep only 'municipal', 'land_value', and 'sitearea_a' columns
rtc_land_price = rtc_land_price[['municipal', 'land_value', 'sitearea_a']]

rtc_land_price
# Out:
#        municipal  land_value  sitearea_a
# 0     somerville  31775500.0       11.59
# 1     somerville   7341100.0        7.69
# 2     somerville   8492300.0        2.25
# 3     somerville   4197200.0        3.37
# 4     somerville   2618400.0        2.07
# ...          ...         ...         ...
# 1181   braintree    155300.0        0.48
# 1182   braintree    222700.0        1.42
# 1183   braintree    223300.0        0.26
# 1184   braintree    164200.0        0.25
# 1185   braintree     94300.0        0.29
#
# [477 rows x 3 columns]

# %% [markdown]
# For these data, classify and sum them according to community (municipality), and then divide the land_value of each community (municipality) by sitearea_a to get the average price per acre of land avg_price.

# %%
# Group by 'municipal' and sum the 'land_value' and 'sitearea_a' fields
rtc_avg_price = rtc_land_price.groupby('municipal', as_index=False).agg(
    {'land_value': 'sum', 'sitearea_a': 'sum'}
)

# Calculate the average price per acre and add it as a new column
rtc_avg_price['avg_price'] = rtc_avg_price['land_value'] / rtc_avg_price['sitearea_a']

# Capitalize the first letter of each word in the 'municipal' column
rtc_avg_price['municipal'] = rtc_avg_price['municipal'].str.title()

rtc_avg_price
# Out:
#     municipal   land_value  sitearea_a     avg_price
# 0   Braintree   46092000.0      107.33  4.294419e+05
# 1   Brookline  163055800.0       37.54  4.343522e+06
# 2   Cambridge  159859200.0       64.63  2.473452e+06
# 3      Malden   47669500.0       77.83  6.124823e+05
# 4      Newton  221499700.0      120.79  1.833759e+06
# 5      Quincy  104287800.0      187.73  5.555202e+05
# 6      Revere   50457600.0       75.61  6.673403e+05
# 7  Somerville  181873300.0       68.16  2.668329e+06

# %% [markdown]
# Plot the bar chart.

# %%
# Sort the data by average price in descending order
rtc_avg_price_sorted = rtc_avg_price.sort_values(by='avg_price', ascending=False)

# Plot the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(
    rtc_avg_price_sorted['municipal'],
    rtc_avg_price_sorted['avg_price'],
    color='skyblue'
)

# Add data labels on top of each bar
for bar, value in zip(bars, rtc_avg_price_sorted['avg_price']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"${value:,.2f}",  # Format as currency with two decimal places
        ha='center',
        va='bottom',
        fontsize=12
    )

# Customize the plot
plt.title('Average Land Price per Acre by Community', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Average Price per Acre ($)', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **High-Cost Communities**: Brookline
#
# * Brookline may not be ideal for cost-sensitive TOD projects, or TOD projects should focus on high-density, high-return investments to offset higher costs.
#
# **Moderate-Price Areas**: Somerville, Cambridge, and Newton
#
# * These communities present an opportunity to balance cost with development potential, and their moderate land prices and existing developable areas could support larger-scale.
#
# **Cost-Effective Communities**: Revere, Malden, Quincy, and Braintree
#
# * These communities stand out as strong candidates for TOD projects due to their lower average land prices, and offer an opportunity to maximize affordability and ensure financial feasibility.

# %% [markdown]
# # J. Modeling

# %% [markdown]
# To determine the most suitable locations for Transit-Oriented Development (TOD) projects, I will use a two-step modeling framework to identify the best locations for Transit-Oriented Development (TOD) projects. The first step will evaluate and rank candidate communities using key indicators. These include **inbound rate, transit coverage, developable station area, community commercial land use, and land price**. This method ensures that the chosen community balances economic feasibility, development potential, and transit accessibility.
#
# In the second step, I will narrow the analysis to the station level within the chosen community. Specifically, I will use **ridership** data to make sure the model will identify the station with the highest potential for TOD development, considering factors such as daily passenger flow. This phased approach provides a data-driven foundation for selecting TOD locations that maximize impact and efficiency.

# %% [markdown]
# ---
#
# All the dataframes and indicators are ready, now we are starting to create the assess_rtc summary dataframe.

# %%
# Merge the dataframes to create access_rtc based on the updated information
assess_rtc = final_rtc[['community']].merge(
    city_avg_ons[['city', 'avg_ons_percentage']].rename(columns={'city': 'community'}),
    on='community', how='left'
).merge(
    final_rtc[['community', 'percent_of_district_to_be_located_in_station_area']],
    on='community', how='left'
).merge(
    final_rtc[['community', 'developable_station_area']],
    on='community', how='left'
).merge(
    community_land_use_count[['muni', 'count']].rename(columns={'muni': 'community', 'count': 'commercial_land_use'}),
    on='community', how='left'
).merge(
    rtc_avg_price[['municipal', 'avg_price']].rename(columns={'municipal': 'community'}),
    on='community', how='left'
)

# Rename the columns for clarity
assess_rtc.columns = [
    'community', 'inbound_rate', 'coverage', 'developable_station_area',
    'commercial_land_use', 'land_price'
]

# Display the resulting DataFrame
assess_rtc
# Out:
#     community inbound_rate  coverage  developable_station_area  \
# 0   Braintree        2.36%       0.5                     485.0
# 1   Brookline        0.33%       0.9                    1349.0
# 2   Cambridge        3.00%       0.9                    1392.0
# 3      Malden        4.58%       0.5                     484.0
# 4      Newton        0.15%       0.9                    2833.0
# 5      Quincy        1.24%       0.9                    1222.0
# 6      Revere        5.68%       0.5                     457.0
# 7  Somerville        1.59%       0.9                    1314.0
#
#    commercial_land_use    land_price
# 0                    0  4.294419e+05
# 1                    1  4.343522e+06
# 2                    1  2.473452e+06
# 3                    4  6.124823e+05
# 4                    6  1.833759e+06
# 5                    2  5.555202e+05
# 6                    6  6.673403e+05
# 7                    7  2.668329e+06

# %% [markdown]
# Now that assess_rtc is ready, let's start building the community evaluation model.

# %% [markdown]
# ---
#
# **STEP 1-1 Preprocess the Data**
#
# 1-1-1 Convert percentages in inbound_rate to numeric values.

# %%
# Convert percentages in the 'inbound_rate' column to numeric values
assess_rtc['inbound_rate'] = assess_rtc['inbound_rate'].str.rstrip('%').astype(float) / 100

# Display the updated DataFrame
assess_rtc
# Out:
#     community  inbound_rate  coverage  developable_station_area  \
# 0   Braintree        0.0236       0.5                     485.0
# 1   Brookline        0.0033       0.9                    1349.0
# 2   Cambridge        0.0300       0.9                    1392.0
# 3      Malden        0.0458       0.5                     484.0
# 4      Newton        0.0015       0.9                    2833.0
# 5      Quincy        0.0124       0.9                    1222.0
# 6      Revere        0.0568       0.5                     457.0
# 7  Somerville        0.0159       0.9                    1314.0
#
#    commercial_land_use    land_price
# 0                    0  4.294419e+05
# 1                    1  4.343522e+06
# 2                    1  2.473452e+06
# 3                    4  6.124823e+05
# 4                    6  1.833759e+06
# 5                    2  5.555202e+05
# 6                    6  6.673403e+05
# 7                    7  2.668329e+06

# %% [markdown]
# 1-1-2 Normalize all indicators to a [0, 1] scale using **Min-Max normalization**.
#
# For community evaluation, we want to combine indicators with different units and ranges into a single score. Min-Max normalization works well in such cases by avoiding dominance by indicators with larger magnitudes, and it is easy to interpret each indicator's contribution relative to others.

# %%
# Define the columns to normalize
columns_to_normalize = [
    'inbound_rate', 'coverage', 'developable_station_area',
    'commercial_land_use', 'land_price'
]

# Create a copy of the DataFrame to apply normalization
normalized_rtc = assess_rtc.copy()

# Perform Min-Max normalization
for column in columns_to_normalize:
  normalized_rtc[column] = (normalized_rtc[column] - normalized_rtc[column].min()) / (normalized_rtc[column].max() - normalized_rtc[column].min())

# Display the normalized DataFrame
normalized_rtc
# Out:
#     community  inbound_rate  coverage  developable_station_area  \
# 0   Braintree      0.399638       0.0                  0.011785
# 1   Brookline      0.032550       1.0                  0.375421
# 2   Cambridge      0.515371       1.0                  0.393519
# 3      Malden      0.801085       0.0                  0.011364
# 4      Newton      0.000000       1.0                  1.000000
# 5      Quincy      0.197107       1.0                  0.321970
# 6      Revere      1.000000       0.0                  0.000000
# 7  Somerville      0.260398       1.0                  0.360690
#
#    commercial_land_use  land_price
# 0             0.000000    0.000000
# 1             0.142857    1.000000
# 2             0.142857    0.522220
# 3             0.571429    0.046765
# 4             0.857143    0.358786
# 5             0.285714    0.032211
# 6             0.857143    0.060780
# 7             1.000000    0.572009

# %% [markdown]
# In order to ensure that the difference is not exaggerated, a small adjustment is introduced here to smooth the extreme values.
#
# ![1733238769168.jpg](data:image/jpeg;base64,...)
#
# Here, I will use **epsilon = 1e-5** to prevent extremes from being exactly 0 or 1.

# %%
# Apply Min-Max normalization with smoothing for the 'coverage' column and others
epsilon = 1e-5  # Smoothing factor to avoid extreme values of 0 and 1

# Copy the assess_rtc DataFrame for normalized values
smoothed_normalized_rtc = assess_rtc.copy()

# Perform Min-Max normalization with smoothing for all indicators
for column in ['inbound_rate', 'coverage', 'developable_station_area', 'commercial_land_use', 'land_price']:
  smoothed_normalized_rtc[column] = (
      smoothed_normalized_rtc[column] - smoothed_normalized_rtc[column].min()) / (smoothed_normalized_rtc[column].max() - smoothed_normalized_rtc[column].min() + epsilon)

# Display the resulting DataFrame
smoothed_normalized_rtc
# Out:
#     community  inbound_rate  coverage  developable_station_area  \
# 0   Braintree      0.399566  0.000000                  0.011785
# 1   Brookline      0.032544  0.999975                  0.375421
# 2   Cambridge      0.515278  0.999975                  0.393519
# 3      Malden      0.800940  0.000000                  0.011364
# 4      Newton      0.000000  0.999975                  1.000000
# 5      Quincy      0.197071  0.999975                  0.321970
# 6      Revere      0.999819  0.000000                  0.000000
# 7  Somerville      0.260351  0.999975                  0.360690
#
#    commercial_land_use  land_price
# 0             0.000000    0.000000
# 1             0.142857    1.000000
# 2             0.142857    0.522220
# 3             0.571428    0.046765
# 4             0.857142    0.358786
# 5             0.285714    0.032211
# 6             0.857142    0.060780
# 7             0.999999    0.572009

# %% [markdown]
# 1-1-3 Adjustments for "Lower is Better" Indicators
#
# * **commercial_land_use**: Less existing commercial infrastructure means increaseing potential for impactful development.
#
# * **land_price**: Lower land prices reduce development costs, making TOD more financially feasible.

# %%
# Perform normalization with inversion for 'commercial_land_use' and 'land_price'
inverse_columns = ['commercial_land_use', 'land_price']

# Copy the normalized data to apply inversion
inverted_rtc = smoothed_normalized_rtc.copy()

# Apply inverse normalization to the specified columns
for column in inverse_columns:
    inverted_rtc[column] = 1 - smoothed_normalized_rtc[column]

# Display the updated DataFrame
inverted_rtc
# Out:
#     community  inbound_rate  coverage  developable_station_area  \
# 0   Braintree      0.399566  0.000000                  0.011785
# 1   Brookline      0.032544  0.999975                  0.375421
# 2   Cambridge      0.515278  0.999975                  0.393519
# 3      Malden      0.800940  0.000000                  0.011364
# 4      Newton      0.000000  0.999975                  1.000000
# 5      Quincy      0.197071  0.999975                  0.321970
# 6      Revere      0.999819  0.000000                  0.000000
# 7  Somerville      0.260351  0.999975                  0.360690
#
#    commercial_land_use    land_price
# 0             1.000000  1.000000e+00
# 1             0.857143  2.554845e-12
# 2             0.857143  4.777802e-01
# 3             0.428572  9.532354e-01
# 4             0.142858  6.412141e-01
# 5             0.714286  9.677885e-01
# 6             0.142858  9.392198e-01
# 7             0.000001  4.279915e-01

# %% [markdown]
# **STEP 1-2 Assign Weights**
#
# The weights are distributed as follows:
#
# *  **inbound_rate: 20%**
#
#   * I believe understanding how reliant a community already is on public transit is essential. The inbound rate reflects the percentage of residents using transit, indicating the community's current alignment with TOD principles. While it's important, I see it as a supporting factor rather than the main driver for TOD development, which is why I assigned it a weight of 20%.
# *  **coverage: 25%**
#
#   * Coverage is one of the most critical factors. It measures how much of the community is within reach of a station area, directly impacting accessibility and TOD effectiveness. Communities with high coverage offer greater opportunities for integrated development. This is why I gave it a significant weight of 25%, emphasizing its importance in the TOD projects.
#
# *  **developable_station_area: 15%**
#
#   * Although important, I view the developable station area—the land available for development near stations—as somewhat secondary. Even communities with smaller station areas can succeed with TOD if they have strong connectivity and other supportive factors. For this reason, I assigned it a moderate weight of 15%.
#
# *  **commercial_land_use: 10%**
#
#   * I consider commercial land use a useful but less critical indicator. A lower level of existing commercial land use suggests more untapped potential for TOD development, but it's not a deciding factor. TOD can adapt to varying levels of commercial infrastructure, so I gave this indicator a lower weight of 10%.
#
# *  **land_price: 30%**
#
#   * In my opinion, land price is one of the most decisive factors for TOD feasibility. Affordable land significantly reduces development costs, making projects more viable and attractive. This is why I assigned it a weight of 30%, highlighting the need to focus on financial feasibility when selecting communities for TOD.

# %%
# Define the weights as a dictionary
weights_data = {
    'Indicator': [
        'inbound_rate',
        'coverage',
        'developable_station_area',
        'commercial_land_use',
        'land_price'
    ],
    'Weight': [
        0.20,  # Inbound Rate
        0.25,  # Coverage
        0.15,  # Developable Station Area
        0.10,  # Commercial Land Use
        0.30   # Land Price
    ]
}

# Create the weights DataFrame
weights = pd.DataFrame(weights_data)

# Display the DataFrame
print(weights)
# Out:
#                   Indicator  Weight
# 0              inbound_rate    0.20
# 1                  coverage    0.25
# 2  developable_station_area    0.15
# 3       commercial_land_use    0.10
# 4                land_price    0.30

# %% [markdown]
# **STEP 1-3 Calculate Community Scores**

# %%
# Calculate the weighted score for each community and add it as a new column named 'scores'
inverted_rtc['scores'] = ((
    inverted_rtc['inbound_rate'] * weights.loc[weights['Indicator'] == 'inbound_rate', 'Weight'].iloc[0] +
    inverted_rtc['coverage'] * weights.loc[weights['Indicator'] == 'coverage', 'Weight'].iloc[0] +
    inverted_rtc['developable_station_area'] * weights.loc[weights['Indicator'] == 'developable_station_area', 'Weight'].iloc[0] +
    inverted_rtc['commercial_land_use'] * weights.loc[weights['Indicator'] == 'commercial_land_use', 'Weight'].iloc[0] +
    inverted_rtc['land_price'] * weights.loc[weights['Indicator'] == 'land_price', 'Weight'].iloc[0]
) * 100)

# Display the updated DataFrame with scores included
inverted_rtc
# Out:
#     community  inbound_rate  coverage  developable_station_area  \
# 0   Braintree      0.399566  0.000000                  0.011785
# 1   Brookline      0.032544  0.999975                  0.375421
# 2   Cambridge      0.515278  0.999975                  0.393519
# 3      Malden      0.800940  0.000000                  0.011364
# 4      Newton      0.000000  0.999975                  1.000000
# 5      Quincy      0.197071  0.999975                  0.321970
# 6      Revere      0.999819  0.000000                  0.000000
# 7  Somerville      0.260351  0.999975                  0.360690
#
#    commercial_land_use    land_price     scores
# 0             1.000000  1.000000e+00  48.168089
# 1             0.857143  2.554845e-12  39.852996
# 2             0.857143  4.777802e-01  64.112539
# 3             0.428572  9.532354e-01  49.072042
# 4             0.142858  6.412141e-01  60.664381
# 5             0.714286  9.677885e-01  69.946859
# 6             0.142858  9.392198e-01  49.601563
# 7             0.000001  4.279915e-01  48.456501

# %% [markdown]
# **STEP 1-4 Rank Communities**

# %%
# Sort the communities by their scores in descending order
ranked_rtc = inverted_rtc.sort_values(by='scores', ascending=False)

# Add a rank column
ranked_rtc['rank'] = ranked_rtc['scores'].rank(ascending=False, method='min').astype(int)

# Display the ranked DataFrame
print(ranked_rtc[['community', 'scores', 'rank']])
# Out:
#     community     scores  rank
# 5      Quincy  69.946859     1
# 2   Cambridge  64.112539     2
# 4      Newton  60.664381     3
# 6      Revere  49.601563     4
# 3      Malden  49.072042     5
# 7  Somerville  48.456501     6
# 0   Braintree  48.168089     7
# 1   Brookline  39.852996     8

# %%
# Sort the DataFrame by scores in descending order
ranked_rtc = ranked_rtc.sort_values(by='scores', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(ranked_rtc['community'], ranked_rtc['scores'], color='skyblue')

# Highlight the highest-ranked station with a different color
bars[0].set_color('#FF7F7F')

# Add scores as annotations on top of the bars
for bar, score in zip(bars, ranked_rtc['scores']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Center of the bar
        bar.get_height(),                  # Height of the bar
        f"{score:.2f}",                    # Format the score to two decimal places
        ha='center', va='bottom', fontsize=10
    )

# Customize the chart
plt.title('Community Rankings Based on TOD Suitability', fontsize=14)
plt.xlabel('Community', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# **Quincy** gets the highest score with 69.95 so that, in this case, we can identify Quincy as the most suitable community for Transit-Oriented Development (TOD) based on community-level indicators, the next step is to determine the best station within Quincy for the project. This step focuses on station-level data, including ridership patterns and station accessibility.

# %% [markdown]
# **STEP 2-1 Identify Stations within the Quincy Community**
#
# Select the zip_code whose city is Quincy from rtc_data.

# %%
# Filter rtc_data to select rows where the city is Quincy
quincy_zip_codes = rtc_data[rtc_data['city'] == 'Quincy']

# Display the filtered DataFrame
quincy_zip_codes
# Out:
#     zip_code postal_area_name    city   county   chia_region
# 499    02169           Quincy  Quincy  Norfolk   Metro South
# 500    02170           Quincy  Quincy  Norfolk   Metro South
# 501    02171           Quincy  Quincy  Norfolk  Metro Boston
# 540    02269           Quincy  Quincy  Norfolk   Metro South

# %%
# Filter stations_in_rtc to select rows with zip_code matching those in quincy_zip_codes
quincy_stations = stations_in_rtc[stations_in_rtc['zip_code'].isin(quincy_zip_codes['zip_code'])]

# Display the filtered DataFrame
quincy_stations
# Out:
#          stop_name parent_station route_id  position_x  position_y zip_code
# 78    North Quincy    place-nqncy      Red  -71.030200   42.275800    02171
# 89    Quincy Adams    place-qamnl      Red  -71.008083   42.232894    02269
# 90   Quincy Center    place-qnctr      Red  -71.005556   42.251944    02169
# 120      Wollaston    place-wlsta      Red  -71.019530   42.265638    02170

# %% [markdown]
# Let’s first take a look at where these four stations are located.

# %%
# Initialize a map centered around an average latitude and longitude
map_center = [quincy_stations['position_y'].mean(), quincy_stations['position_x'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# Add station points to the map
for _, row in quincy_stations.iterrows():
    folium.Marker(
        location=[row['position_y'], row['position_x']],
        popup=f"Station: {row['stop_name']}<br>ZIP Code: {row['zip_code']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mymap)

# Display the map directly in Colab
display(mymap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77326331bf2781e3b80b44973bed4aed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77326331bf2781e3b80b44973bed4aed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77326331bf2781e3b80b44973bed4aed = L.map(
#                 &quot;map_77326331bf2781e3b80b44973bed4aed&quot;,
#                 {
#                     center: [42.256569, -71.01584224999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5cc2aa7bae8ea94392b73bff1990b28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d5cc2aa7bae8ea94392b73bff1990b28.addTo(map_77326331bf2781e3b80b44973bed4aed);
#
#
#             var marker_0976d4456e1be8df5cc610516c6c9ae8 = L.marker(
#                 [42.2758, -71.0302],
#                 {}
#             ).addTo(map_77326331bf2781e3b80b44973bed4aed);
#
#
#             var icon_e44b0d7adb0763dae7e94a1349a555bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0976d4456e1be8df5cc610516c6c9ae8.setIcon(icon_e44b0d7adb0763dae7e94a1349a555bc);
#
#
#         var popup_adaeda7ad3030cdc9b105e26455ba45c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6ad99285dbce823bd077ca35b86d49c = $(`&lt;div id=&quot;html_e6ad99285dbce823bd077ca35b86d49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: North Quincy&lt;br&gt;ZIP Code: 02171&lt;/div&gt;`)[0];
#                 popup_adaeda7ad3030cdc9b105e26455ba45c.setContent(html_e6ad99285dbce823bd077ca35b86d49c);
#
#
#
#         marker_0976d4456e1be8df5cc610516c6c9ae8.bindPopup(popup_adaeda7ad3030cdc9b105e26455ba45c)
#         ;
#
#
#
#
#             var marker_6dce385ce624faeba26da2d6f7d1d7d8 = L.marker(
#                 [42.232894, -71.008083],
#                 {}
#             ).addTo(map_77326331bf2781e3b80b44973bed4aed);
#
#
#             var icon_d674baad34bd9b88112f5d5f38482537 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6dce385ce624faeba26da2d6f7d1d7d8.setIcon(icon_d674baad34bd9b88112f5d5f38482537);
#
#
#         var popup_01588f2a3b44d8283fffdb2497220a9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c4517ffd48462189a30a9cc4c1959c7 = $(`&lt;div id=&quot;html_3c4517ffd48462189a30a9cc4c1959c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Quincy Adams&lt;br&gt;ZIP Code: 02269&lt;/div&gt;`)[0];
#                 popup_01588f2a3b44d8283fffdb2497220a9f.setContent(html_3c4517ffd48462189a30a9cc4c1959c7);
#
#
#
#         marker_6dce385ce624faeba26da2d6f7d1d7d8.bindPopup(popup_01588f2a3b44d8283fffdb2497220a9f)
#         ;
#
#
#
#
#             var marker_236291272c65549bbedd4aedf8a5817a = L.marker(
#                 [42.251944, -71.005556],
#                 {}
#             ).addTo(map_77326331bf2781e3b80b44973bed4aed);
#
#
#             var icon_015977a1f3ec0fc5d2413d1fd5aaf897 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_236291272c65549bbedd4aedf8a5817a.setIcon(icon_015977a1f3ec0fc5d2413d1fd5aaf897);
#
#
#         var popup_c057f1418f242519b5a2dffc75e4f8a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97690d8b239e9b8a321fbd55ad7009ad = $(`&lt;div id=&quot;html_97690d8b239e9b8a321fbd55ad7009ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Quincy Center&lt;br&gt;ZIP Code: 02169&lt;/div&gt;`)[0];
#                 popup_c057f1418f242519b5a2dffc75e4f8a5.setContent(html_97690d8b239e9b8a321fbd55ad7009ad);
#
#
#
#         marker_236291272c65549bbedd4aedf8a5817a.bindPopup(popup_c057f1418f242519b5a2dffc75e4f8a5)
#         ;
#
#
#
#
#             var marker_55d39381808a6d5d2f3f56569d2b1e6b = L.marker(
#                 [42.265638, -71.01953],
#                 {}
#             ).addTo(map_77326331bf2781e3b80b44973bed4aed);
#
#
#             var icon_a50100067e32a282b2b623c8aba4727d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quo

# %% [markdown]
# Now, filter out the station data of stop_name in quincy_stations from mbta_rider, and keep the column names day_type_name, time_period_name, stop_name, total_ons, total_offs, and store them in a new dataframe.

# %%
# Filter mbta_rider to select rows where stop_name matches those in quincy_stations
quincy_rider_data = mbta_rider[mbta_rider['stop_name'].isin(quincy_stations['stop_name'])]

# Select the required columns
quincy_rider_data = quincy_rider_data[['day_type_name', 'time_period_name', 'stop_name', 'total_ons', 'total_offs']]

# Display the filtered DataFrame
quincy_rider_data
# Out:
#      day_type_name    time_period_name      stop_name  total_ons  total_offs
# 609        Weekday             AM_PEAK   North Quincy      32044        4669
# 612        Weekday             AM_PEAK   Quincy Adams      20603         264
# 613        Weekday             AM_PEAK  Quincy Center      39544        1251
# 617        Weekday             AM_PEAK      Wollaston      28316        1449
# 639        Weekday  VERY_EARLY_MORNING   North Quincy       4353         212
# ...            ...                 ...            ...        ...         ...
# 1177       Weekday             PM_PEAK      Wollaston       4207       36068
# 1191       Weekday             EVENING   North Quincy       2476       27798
# 1194       Weekday             EVENING   Quincy Adams        162       16821
# 1195       Weekday             EVENING  Quincy Center       1080       27947
# 1199       Weekday             EVENING      Wollaston       2639       25104
#
# [88 rows x 5 columns]

# %% [markdown]
# 2-1-1 Define the indicators.
#
# In this evaluation session, my idea is to select the average daily passenger flow as the primary indicator, and the secondary indicators are the average daily passenger flow on weekends and two ratios assessing the passenger stability - weekday peak hour flow: off-peak hour flow and weekday average passenger volume: weekend average passenger volume.
#
# **Total Activity**: Captured by daily and weekend ridership.
#
# **Usage Patterns**: Addressed by peak/off-peak and weekday/weekend stability.
#
# **Average Daily Ridership (Primary Metric)**
#
#   * This is the most critical indicator as it reflects the total activity at each station. High daily ridership indicates that the station serves a central role in the transit network, making it a focal point for community interactions.
#
# **Average Weekend Ridership (Secondary Metric)**
#
#   * Weekend ridership highlights a station's relevance beyond commuter traffic, such as leisure or retail activities. Stations with higher weekend usage demonstrate a more balanced and diverse rider base for mixed-use developments.
#
# **Passenger Stability 1 (Peak-to-Off-Peak Ratio)**
#
#   * This ratio compares weekday peak-hour ridership to off-peak ridership. A balanced ratio reflects a station that supports consistent activity throughout the day, making it ideal for TOD.
#
# **Passenger Stability 2 (Weekday-to-Weekend Ratio)**
#
#   * This metric compares average weekday ridership to weekend ridership, providing insights into the station's usage patterns across the week. A low ratio suggests the station is versatile, catering to both commuters and leisure travelers, making it a stronger candidate for TOD.

# %% [markdown]
# **Reminder**
# This dataset contains detailed ridership data for heavy rail and light rail during the **Fall 2023** rating ***(August 27-December 16, 112 days in total)***.
#   * For this period, **non-holiday weekdays** were 80 weekdays - 3 holidays (Labor Day, Columbus Day, Thanksgiving) = **77 days**
#
#   * **Saturdays** were **16 days** in total (Veterans Day falls on a Saturday, so no adjustment).
#
#   * **Sunday** were also **16 days** in total.

# %%
# Constants
total_weekday = 77
total_weekend = 32  # 16 Saturdays + 16 Sundays
total_days = total_weekday + total_weekend

# Filter weekday and weekend data
weekday_rider_data = quincy_rider_data[quincy_rider_data['day_type_name'] == 'Weekday']
weekend_rider_data = quincy_rider_data[quincy_rider_data['day_type_name'].str.contains('Saturday|Sunday', case=False)]

# 1. Calculate Average Daily Ridership
daily_avg_ridership = quincy_rider_data.groupby('stop_name')[['total_ons', 'total_offs']].sum()
daily_avg_ridership['avg_daily_ridership'] = (
    daily_avg_ridership['total_ons'] + daily_avg_ridership['total_offs']
) / total_days

# 2. Calculate Average Weekend Ridership
weekend_avg_ridership = weekend_rider_data.groupby('stop_name')[['total_ons', 'total_offs']].sum()
weekend_avg_ridership['avg_weekend_ridership'] = (
    weekend_avg_ridership['total_ons'] + weekend_avg_ridership['total_offs']
) / total_weekend

# 3. Calculate Passenger Stability 1: Weekday Peak to Off-Peak Ratio
weekday_peak_data = weekday_rider_data[weekday_rider_data['time_period_name'].str.contains('AM_PEAK|PM_PEAK', case=False)]
weekday_off_peak_data = weekday_rider_data[
    ~weekday_rider_data['time_period_name'].str.contains('AM_PEAK|PM_PEAK', case=False)
]

weekday_peak_totals = weekday_peak_data.groupby('stop_name')[['total_ons', 'total_offs']].sum()
weekday_peak_totals['avg_peak_ridership'] = (
    weekday_peak_totals['total_ons'] + weekday_peak_totals['total_offs']
) / total_weekday

weekday_off_peak_totals = weekday_off_peak_data.groupby('stop_name')[['total_ons', 'total_offs']].sum()
weekday_off_peak_totals['avg_off_peak_ridership'] = (
    weekday_off_peak_totals['total_ons'] + weekday_off_peak_totals['total_offs']
) / total_weekday

stability_1 = weekday_peak_totals[['avg_peak_ridership']].copy()
stability_1['peak_to_off_peak_ratio'] = stability_1['avg_peak_ridership'] / weekday_off_peak_totals['avg_off_peak_ridership']

# 4. Calculate Passenger Stability 2: Weekday to Weekend Ratio
weekday_totals = weekday_rider_data.groupby('stop_name')[['total_ons', 'total_offs']].sum()
weekday_totals['avg_weekday_ridership'] = (
    weekday_totals['total_ons'] + weekday_totals['total_offs']
) / total_weekday

stability_2 = weekday_totals[['avg_weekday_ridership']].copy()
stability_2['weekday_to_weekend_ratio'] = stability_2['avg_weekday_ridership'] / weekend_avg_ridership['avg_weekend_ridership']

# Merge all metrics into a single DataFrame
metrics_df = daily_avg_ridership[['avg_daily_ridership']].merge(
    weekend_avg_ridership[['avg_weekend_ridership']],
    left_index=True, right_index=True, how='left'
).merge(
    stability_1[['peak_to_off_peak_ratio']],
    left_index=True, right_index=True, how='left'
).merge(
    stability_2[['weekday_to_weekend_ratio']],
    left_index=True, right_index=True, how='left'
)

# Display the combined metrics DataFrame
metrics_df
# Out:
#                avg_daily_ridership  avg_weekend_ridership  \
# stop_name
# North Quincy           2734.284404             1175.62500
# Quincy Adams           1507.055046              632.25000
# Quincy Center          3366.165138             1660.09375
# Wollaston              2439.394495             1134.87500
#
#                peak_to_off_peak_ratio  weekday_to_weekend_ratio
# stop_name
# North Quincy                 0.693747                  2.876801
# Quincy Adams                 0.691647                  2.958656
# Quincy Center                0.574598                  2.454790
# Wollaston                    0.630722                  2.627190

# %% [markdown]
# 2-1-2 Normalization.
#
# Please note: avg_daily_ridership and avg_weekend_ridership are numerical indexes, which could apply Min-Max Normalization. But peak_to_off_peak_ratio and weekday_to_weekend_ratio are both ratios, and the standard is that the closer to 1 the better so we need to use Closeness to 1 Normalization.

# %%
# Perform normalization for all four indicators
# Normalization for avg_daily_ridership and avg_weekend_ridership: Min-Max normalization
# Normalization for peak_to_off_peak_ratio and weekday_to_weekend_ratio: Adjust to measure closeness to 1

normalized_metrics_df = metrics_df.copy()

# 1. Min-Max Normalization for avg_daily_ridership and avg_weekend_ridership
for metric in ['avg_daily_ridership', 'avg_weekend_ridership']:
    min_value = metrics_df[metric].min()
    max_value = metrics_df[metric].max()
    normalized_metrics_df[metric] = (metrics_df[metric] - min_value) / (max_value - min_value)

# 2. Closeness to 1 Normalization for ratios
for metric in ['peak_to_off_peak_ratio', 'weekday_to_weekend_ratio']:
    normalized_metrics_df[metric] = 1 - abs(metrics_df[metric] - 1)

# Display the normalized metrics DataFrame
normalized_metrics_df
# Out:
#                avg_daily_ridership  avg_weekend_ridership  \
# stop_name
# North Quincy              0.660117               0.528655
# Quincy Adams              0.000000               0.000000
# Quincy Center             1.000000               1.000000
# Wollaston                 0.501498               0.489009
#
#                peak_to_off_peak_ratio  weekday_to_weekend_ratio
# stop_name
# North Quincy                 0.693747                 -0.876801
# Quincy Adams                 0.691647                 -0.958656
# Quincy Center                0.574598                 -0.454790
# Wollaston                    0.630722                 -0.627190

# %% [markdown]
# **STEP 2-2 Assign Weights**
#
# The weights are distributed as follows:
#
# *  **avg_daily_ridership: 40%**
#
#   * I believe that average daily ridership is the most critical factor in ranking Quincy stations, as it directly measures the total activity and the station's importance within the transit network. This is why I have assigned it the highest weight of 40%.
#
# *  **avg_weekend_ridership: 20%**
#
#   * Average weekend ridership, while secondary, is still essential as it reflects the station's relevance beyond weekday commuter traffic. This helps identify stations that cater to a broader range of activities, such as leisure and shopping. I have allocated it a weight of 20%, acknowledging its role in assessing the station's versatility.
#
# *  **peak_to_off_peak_ratio: 20%**
#
#   * Passenger stability 1 (peak-to-off-peak ratio) is another important indicator, receiving a weight of 20%. A balanced ratio reflects consistent activity throughout the day, indicating a station's potential to support TOD.
#
# *  **weekday_to_weekend_ratio: 20%**
#
#   * Passenger stability 2 (weekday-to-weekend ratio) is equally weighted at 20%. This metric ensures that stations with diverse rider profiles, serving both commuters and non-commuters, are given due consideration. A balanced weekday-to-weekend ratio aligns well with the TOD goal of creating vibrant, multi-purpose areas.

# %%
# Define weights for each indicator
weights_stations = {
    'avg_daily_ridership': 0.40,
    'avg_weekend_ridership': 0.20,
    'peak_to_off_peak_ratio': 0.20,
    'weekday_to_weekend_ratio': 0.20
}

# Create the weights DataFrame
weights_station = pd.DataFrame([weights_stations]).T
# Set the column name
weights_station.columns = ['Weight']

# Display the DataFrame
weights_station
# Out:
#                           Weight
# avg_daily_ridership          0.4
# avg_weekend_ridership        0.2
# peak_to_off_peak_ratio       0.2
# weekday_to_weekend_ratio     0.2

# %% [markdown]
# **STEP 2-3 Calculate Station Scores**

# %%
# Calculate the weighted score for each station
normalized_metrics_df['final_score'] = ((
    normalized_metrics_df['avg_daily_ridership'] * weights_stations['avg_daily_ridership'] +
    normalized_metrics_df['avg_weekend_ridership'] * weights_stations['avg_weekend_ridership'] +
    normalized_metrics_df['peak_to_off_peak_ratio'] * weights_stations['peak_to_off_peak_ratio'] +
    normalized_metrics_df['weekday_to_weekend_ratio'] * weights_stations['weekday_to_weekend_ratio']
) * 100 + 100 * 0.2)

# Sort the stations by their final score in descending order
ranked_stations = normalized_metrics_df.sort_values(by='final_score', ascending=False)

ranked_stations
# Out:
#                avg_daily_ridership  avg_weekend_ridership  \
# stop_name
# Quincy Center             1.000000               1.000000
# North Quincy              0.660117               0.528655
# Wollaston                 0.501498               0.489009
# Quincy Adams              0.000000               0.000000
#
#                peak_to_off_peak_ratio  weekday_to_weekend_ratio  final_score
# stop_name
# Quincy Center                0.574598                 -0.454790    82.396153
# North Quincy                 0.693747                 -0.876801    53.316693
# Wollaston                    0.630722                 -0.627190    49.910737
# Quincy Adams                 0.691647                 -0.958656    14.659822

# %% [markdown]
# **STEP 2-4 Rank Stations**

# %%
# Sort the stations by their final score in descending order
ranked_stations = normalized_metrics_df.sort_values(by='final_score', ascending=False)

# Display the ranked stations DataFrame
ranked_stations
# Out:
#                avg_daily_ridership  avg_weekend_ridership  \
# stop_name
# Quincy Center             1.000000               1.000000
# North Quincy              0.660117               0.528655
# Wollaston                 0.501498               0.489009
# Quincy Adams              0.000000               0.000000
#
#                peak_to_off_peak_ratio  weekday_to_weekend_ratio  final_score
# stop_name
# Quincy Center                0.574598                 -0.454790    82.396153
# North Quincy                 0.693747                 -0.876801    53.316693
# Wollaston                    0.630722                 -0.627190    49.910737
# Quincy Adams                 0.691647                 -0.958656    14.659822

# %%
# Sort the ranked stations DataFrame for plotting
ranked_stations = ranked_stations.sort_values(by='final_score', ascending=False)

# Plot the ranked stations
plt.figure(figsize=(10, 6))
bars = plt.bar(ranked_stations.index, ranked_stations['final_score'], color='skyblue')

# Highlight the highest-ranked station with a different color
bars[0].set_color('#FF7F7F')

# Add annotations to the bars
for bar, score in zip(bars, ranked_stations['final_score']):
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Center of the bar
        bar.get_height(),                  # Height of the bar
        f"{score:.2f}",                    # Format the score to two decimal places
        ha='center', va='bottom', fontsize=12
    )

# Customize the plot
plt.title('Ranked Quincy Stations by Final Score', fontsize=14)
plt.xlabel('Station Name', fontsize=12)
plt.ylabel('Final Score', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # K. Discussion

# %%
import folium

# Extract Quincy Center's latitude and longitude from the dataframe
quincy_center = stations_in_rtc[stations_in_rtc['stop_name'] == 'Quincy Center'].iloc[0]
latitude = quincy_center['position_y']  # Replace with the column for latitude
longitude = quincy_center['position_x']  # Replace with the column for longitude

# Create a map centered on Quincy Center
map_quincy_center = folium.Map(location=[latitude, longitude], zoom_start=15)

# Add a marker for Quincy Center
folium.Marker(
    location=[latitude, longitude],
    popup="Quincy Center Station",
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(map_quincy_center)

# Display the map
map_quincy_center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc3503bc76e5b8c9d2b0decc2f5df56b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc3503bc76e5b8c9d2b0decc2f5df56b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc3503bc76e5b8c9d2b0decc2f5df56b = L.map(
#                 &quot;map_dc3503bc76e5b8c9d2b0decc2f5df56b&quot;,
#                 {
#                     center: [42.251944, -71.005556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_027373221c4013efc1fc09151bc4d5ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_027373221c4013efc1fc09151bc4d5ec.addTo(map_dc3503bc76e5b8c9d2b0decc2f5df56b);
#
#
#             var marker_71db14a10b9993ec3f4da5d234036284 = L.marker(
#                 [42.251944, -71.005556],
#                 {}
#             ).addTo(map_dc3503bc76e5b8c9d2b0decc2f5df56b);
#
#
#             var icon_563a10dbca9175737fcec42b8a9a5156 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_71db14a10b9993ec3f4da5d234036284.setIcon(icon_563a10dbca9175737fcec42b8a9a5156);
#
#
#         var popup_e2b7f28346c02beb39710619d607b0af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_125abb349ceae888df83e5c093b1aa5c = $(`&lt;div id=&quot;html_125abb349ceae888df83e5c093b1aa5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quincy Center Station&lt;/div&gt;`)[0];
#                 popup_e2b7f28346c02beb39710619d607b0af.setContent(html_125abb349ceae888df83e5c093b1aa5c);
#
#
#
#         marker_71db14a10b9993ec3f4da5d234036284.bindPopup(popup_e2b7f28346c02beb39710619d607b0af)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Quincy ranked as the best community for TOD suitability with a score of 69.95, outperforming other top candidates such as Cambridge (64.11) and Newton (60.66). This result highlights Quincy's high inbound rate, developable station areas, and relatively favorable land prices.
#
# Within Quincy, Quincy Center Station emerged as the top choice for TOD, with a final station score of 82.40. This high score is attributed to its strong ridership metrics, including high average daily and weekend usage, and its stability in passenger flows across peak and off-peak periods.

# %% [markdown]
# # L. Cost Analysis

# %% [markdown]
# **1. Development Area and Land Requirements**
#
# Similar projects near Quincy Center and well-known developments like the Prudential Center provide useful examples. They help in understanding the project's size and the land needed for it.
#
# * **Prudential Center**
#
#   The Prudential Center spans 3.6 million square feet, with 3 million square feet allocated to office space and 680,000 square feet to retail. Given Quincy Center's smaller market size and population density, a 500,000 square foot project is more appropriate, focusing on a balanced mix of residential, office, and retail spaces.
#
# * **119 Parkingway Project (local)**
#
#   A seven-story, mixed-use development with 300 residential units and 14,000 square feet of retail space.119 Parkingway.
#
# * **1469 Hancock Street Project (local)**
#
#   A 15-story building with 204 residential units.
#
# These examples highlight the feasibility of mid-sized TOD projects in Quincy Center. With a Floor Area Ratio (FAR) of 3, the required land area is:
#
# * **Total Land Area = Total Floor Area / FAR = 500,000 / 3 ≈ 166,667 sqft ≈ 3.8 acres**

# %% [markdown]
# **2. Construction Costs**
#
# * **Benchmarks**
#
#   * Single-story commercial buildings: $$301-361 per square foot.
#   * Mid-rise commercial buildings: $599-719 per square foot.
#   * High-rise buildings: $688-827 per square foot.
#
# * **Prudential Center Reference**
#
#   The high-quality design and complexity of the Prudential Center suggest a construction cost closer to the upper range for mid-rise buildings.
#
# * **Estimated Cost for Quincy Center**
#
#   The estimated cost for a mixed-use facility with a similar emphasis on quality is **$700 per square foot**.

# %% [markdown]
# **3. Land Costs**
#
# Land prices in Quincy Center are moderate compared to Boston's Back Bay but remain a critical factor.
#
# * **Price Per Acre: $555,520.16**
#
# * **Total Land Cost = 3.8 acres * 555,520.16 $/acre = $$2,110,976,61**

# %% [markdown]
# **4. Soft Costs and Additional Expenses**
#
# * Soft costs: $70,000,000
#
# * Infrastructure and utility costs: $35,000,000
#
# * Financing costs: $17,500,000
#
# * Marketing and pre-operational costs: $7,000,000
#
# * **Total soft costs: $129,500,000**

# %% [markdown]
# **5. Total Project Cost**
#
# ![1733897838151.png](data:image/png;base64,...)

# %% [markdown]
# **6. Functional Distribution**
#
# We can use the functional layout of the Prudential Center as a reference to plan the space for Quincy Center TOD. The plan includes allocating 100,000 square feet for retail space to meet local commercial needs. Additionally, 400,000 square feet will be designated for residential and office use to support community growth and job creation. This distribution aims to balance economic feasibility with market demand and strengthen Quincy Center's role as a regional hub.

# %% [markdown]
# # M. Conclusion
#
# As the designer of the proposed Quincy Center TOD project, I believe it offers a balanced, scalable, and economically viable development opportunity. Drawing inspiration from the Prudential Center and similar local projects, I have estimated a total cost of $482 million. This estimate aligns with current market conditions and reflects a carefully designed mixed-use plan tailored to Quincy Center's needs. By applying insights from successful developments and focusing on stakeholder engagement, the goal is to create a sustainable and dynamic urban hub that improves community accessibility and drives economic growth. I recommend conducting detailed feasibility studies and engaging stakeholders to refine cost estimates and support the project's successful implementation.
